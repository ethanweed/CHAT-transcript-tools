# %%
from os import chdir as cd
pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/POS-Letty/'
file = '_files-with-errors.txt'


cd(pathin)

with open(file,'r') as f:
    ef = f.read()

ef = ef.replace('list index out of range in ', '')
ef = ef.split('\n')

# %%
pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/raw_cohorts_2_3/'
cd(pathin)

removelist = ['\t', '\r']
file = 'Lester.Visit6.txt'
with open(file,'r') as f:
    text = f.read()
    for item in removelist:
        text = text.replace(item, '')
text = text.split('\n')
print(text)
# Out:
# ['@UTF8', '@Begin', '@Languages:eng', '@Participants:CHI Lester Target_Child, MOT Mother, INV1 Investigator, INV2', 'Investigator', '@ID:eng|Lester|CHI|||||Target_Child||', '@ID:eng|Lester|MOT|||||Mother||', '@ID:eng|Lester|INV1|||||Investigator||', '@ID:eng|Lester|INV2|||||Investigator||', 'Coder:Malory Delgado', 'Reliability coder:', 'Language and Autism Study', 'Sex of CHI: Male', 'Age of CHI:', 'Situation:Mother Child Interaction (Visit 6)', '*MOT:do you want to feed them first ?', '%mor:aux|do pro|you v|want inf|to v|feed pro:obj|them adv|first ?', '*MOT:then go to sleep .', '%mor:adv:tem|then v|go inf|to v|sleep .', '*CHI:yeah .', '%mor:co|yeah .', '*MOT:okay .', '%mor:co|okay .', "*MOT:here's the baby bottle .", '%mor:adv:loc|here~v:cop|be&3S det|the n|baby n|bottle .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:okay .', '%mor:co|okay .', '*MOT:now give .', '%mor:adv|now v|give .', '*MOT:you gotta burp the baby .', '%mor:pro|you v|get&PAST~inf|to v|burp det|the n|baby .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:oh my goodness that baby burps so crazy .', '%mor:co|oh pro:poss:det|my n|good&dadj-NESS det|that n|baby v|burp-3S', 'adv:int|so  adj|craze&dn-Y .', '*MOT:now is the pillow all set ?', '%mor:adv|now v:cop|be&3S det|the n|pillow adv:int|all adj|set ?', '*MOT:is the blanket all nice ?', '%mor:v:cop|be&3S det|the n|blanket adv:int|all adj|nice ?', '*CHI:xxx .', '*MOT:mhm .', '%mor:co|yes .', "*MOT:and what's that ?", '%mor:coord|and pro:wh|what~v:cop|be&3S pro:dem|that ?', '*MOT:is that a pillow ?', '%mor:v:cop|be&3S pro:dem|that det|a n|pillow ?', '*CHI:yeah .', '%mor:co|yeah .', '*CHI:see .', '%mor:v|see .', '*CHI:xxx need to be over here .', '%mor:v|need inf|to v:cop|be prep|over adv:loc|here .', '*CHI:the baby need to be right here .', '%mor:det|the n|baby v|need inf|to v:cop|be adv|right adv:loc|here .', '*CHI:and a blanket .', '%mor:coord|and det|a n|blanket .', '*MOT:okay, very good .', '%mor:co|okay cm|cm adv:int|very adj|good .', '*CHI:xxx .', "*MOT:you're gonna be a very good daddy someday .", '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v:cop|be det|a adv:int|very adj|good', 'n|daddy adv:tem|someday .', '*MOT:huh ?', '%mor:co|huh ?', '*MOT:very nice .', '%mor:adv:int|very adj|nice .', '*CHI:I think the baby is hungry .', '%mor:pro:sub|I v|think det|the n|baby v:cop|be&3S adj|hungry .', '*MOT:the baby just ate .', '%mor:det|the n|baby adv:int|just v|eat&PAST .', '*MOT:and you just burped the baby .', '%mor:coord|and pro|you adv:int|just v|burp-PAST det|the n|baby .', '*MOT:the baby is hungry again ?', '%mor:det|the n|baby v:cop|be&3S adj|hungry adv|again ?', '*CHI:xxx .', '*MOT:gulp gulp gulp .', '%mor:n|gulp n|gulp n|gulp .', '*MOT:oh .', '%mor:co|oh .', '*MOT:baby burped .', '%mor:n|baby v|burp-PAST .', '*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .', '*MOT:can you .', '%mor:aux|can pro|you .', '*MOT:can you stack these blocks up ?', '%mor:aux|can pro|you v|stack det|these n|block-PL prep|up ?', '*MOT:with the biggest one on the bottom .', '%mor:prep|with det|the adj|big-SP pro:indef|one prep|on det|the n|bottom .', '*MOT:and the smallest one on the top .', '%mor:coord|and det|the adj|small-SP pro:indef|one prep|on det|the n|top .', '*CHI:oh .', '%mor:co|oh .', '*MOT:biggest one on the bottom .', '%mor:adj|big-SP pro:indef|one prep|on det|the n|bottom .', '*MOT:oh, turn it upside down .', '%mor:co|oh cm|cm v|turn pro|it adv|upside adv:loc|down .', '*MOT:so we can stack them up .', '%mor:conj|so pro:sub|we aux|can v|stack pro:obj|them adv:loc|up .', '*MOT:there you go .', '%mor:adv:loc|there pro|you v|go .', '*MOT:big .', '%mor:adj|big .', '*MOT:smaller .', '%mor:adj|small-CP .', '*MOT:smaller .', '%mor:adj|small-CP .', '*MOT:and smallest .', '%mor:coord|and adj|small-SP .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:you did a great job .', '%mor:pro|you v|do&PAST det|a adj|great n|job .', '*MOT:what else can you put on top ?', '%mor:pro:wh|what pos ...

# %%
insertion_points = []
for i, val in enumerate(text):
    if val == '*CHI:xxx .':
        ip = i+1
        insertion_points.append(ip)

# %%
for ip in insertion_points:
    text.insert(ip, '%mor:unk|xxx . ')

# %%
print(text)
# Out:
# ['@UTF8', '@Begin', '@Languages:eng', '@Participants:CHI Lester Target_Child, MOT Mother, INV1 Investigator, INV2', 'Investigator', '@ID:eng|Lester|CHI|||||Target_Child||', '@ID:eng|Lester|MOT|||||Mother||', '@ID:eng|Lester|INV1|||||Investigator||', '@ID:eng|Lester|INV2|||||Investigator||', 'Coder:Malory Delgado', 'Reliability coder:', 'Language and Autism Study', 'Sex of CHI: Male', 'Age of CHI:', 'Situation:Mother Child Interaction (Visit 6)', '*MOT:do you want to feed them first ?', '%mor:aux|do pro|you v|want inf|to v|feed pro:obj|them adv|first ?', '*MOT:then go to sleep .', '%mor:adv:tem|then v|go inf|to v|sleep .', '*CHI:yeah .', '%mor:co|yeah .', '*MOT:okay .', '%mor:co|okay .', "*MOT:here's the baby bottle .", '%mor:adv:loc|here~v:cop|be&3S det|the n|baby n|bottle .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:okay .', '%mor:co|okay .', '*MOT:now give .', '%mor:adv|now v|give .', '*MOT:you gotta burp the baby .', '%mor:pro|you v|get&PAST~inf|to v|burp det|the n|baby .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:oh my goodness that baby burps so crazy .', '%mor:co|oh pro:poss:det|my n|good&dadj-NESS det|that n|baby v|burp-3S', 'adv:int|so  adj|craze&dn-Y .', '*MOT:now is the pillow all set ?', '%mor:adv|now v:cop|be&3S det|the n|pillow adv:int|all adj|set ?', '*MOT:is the blanket all nice ?', '%mor:v:cop|be&3S det|the n|blanket adv:int|all adj|nice ?', '*CHI:xxx .', '%mor:unk|xxx . ', '*MOT:mhm .', '%mor:co|yes .', "*MOT:and what's that ?", '%mor:coord|and pro:wh|what~v:cop|be&3S pro:dem|that ?', '*MOT:is that a pillow ?', '%mor:v:cop|be&3S pro:dem|that det|a n|pillow ?', '*CHI:yeah .', '%mor:co|yeah .', '*CHI:see .', '%mor:v|see .', '*CHI:xxx need to be over here .', '%mor:v|need inf|to v:cop|be prep|over adv:loc|here .', '*CHI:the baby need to be right here .', '%mor:det|the n|baby v|need inf|to v:cop|be adv|right adv:loc|here .', '*CHI:and a blanket .', '%mor:coord|and det|a n|blanket .', '*MOT:okay, very good .', '%mor:co|okay cm|cm adv:int|very adj|good .', '%mor:unk|xxx . ', '*CHI:xxx .', "*MOT:you're gonna be a very good daddy someday .", '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v:cop|be det|a adv:int|very adj|good', 'n|daddy adv:tem|someday .', '*MOT:huh ?', '%mor:co|huh ?', '*MOT:very nice .', '%mor:adv:int|very adj|nice .', '*CHI:I think the baby is hungry .', '%mor:pro:sub|I v|think det|the n|baby v:cop|be&3S adj|hungry .', '*MOT:the baby just ate .', '%mor:det|the n|baby adv:int|just v|eat&PAST .', '*MOT:and you just burped the baby .', '%mor:coord|and pro|you adv:int|just v|burp-PAST det|the n|baby .', '*MOT:the baby is hungry again ?', '%mor:unk|xxx . ', '%mor:det|the n|baby v:cop|be&3S adj|hungry adv|again ?', '*CHI:xxx .', '*MOT:gulp gulp gulp .', '%mor:n|gulp n|gulp n|gulp .', '*MOT:oh .', '%mor:co|oh .', '*MOT:baby burped .', '%mor:n|baby v|burp-PAST .', '*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .', '*MOT:can you .', '%mor:aux|can pro|you .', '*MOT:can you stack these blocks up ?', '%mor:aux|can pro|you v|stack det|these n|block-PL prep|up ?', '*MOT:with the biggest one on the bottom .', '%mor:prep|with det|the adj|big-SP pro:indef|one prep|on det|the n|bottom .', '*MOT:and the smallest one on the top .', '%mor:coord|and det|the adj|small-SP pro:indef|one prep|on det|the n|top .', '*CHI:oh .', '%mor:co|oh .', '*MOT:biggest one on the bottom .', '%mor:adj|big-SP pro:indef|one prep|on det|the n|bottom .', '*MOT:oh, turn it upside down .', '%mor:co|oh cm|cm v|turn pro|it adv|upside adv:loc|down .', '*MOT:so we can stack them up .', '%mor:conj|so pro:sub|we aux|can v|stack pro:obj|them adv:loc|up .', '*MOT:there you go .', '%mor:adv:loc|there pro|you v|go .', '*MOT:big .', '%mor:adj|big .', '*MOT:smaller .', '%mor:adj|small-CP .', '*MOT:smaller .', '%mor:adj|small-CP .', '*MOT:and smallest .', '%mor:coord|and adj|small-SP .', '*MOT:very good .', '%mor:adv:int|very adj|good .', '*MOT:you did a great job .', '%mor:pro|you v|do&PAST det|a adj|great n|job .', '*M ...

# %%
for line in text:
    if line.startswith('@Participants:'):
        p = line.replace('@Participants:', '')
        p = p.split(',')

        p1 = []
        for i, val in enumerate(p):
            v1 = val.replace(' ','')
            v2 = v1.replace('\n', '')
            p1.append(v2[0:3])
people = p1
print(people)
# Out:
# ['CHI', 'MOT', 'INV', 'INV']

# %%
trans = []
for line in text:
    label = line[1:4]
    if label in people:
        trans.append(line)
    elif label == 'mor':
        trans.append(line)

grouped = [trans[n:n+2] for n in range(0, len(trans), 2)]
grouped
# Out:
# [['*MOT:do you want to feed them first ?',
#   '%mor:aux|do pro|you v|want inf|to v|feed pro:obj|them adv|first ?'],
#  ['*MOT:then go to sleep .', '%mor:adv:tem|then v|go inf|to v|sleep .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ["*MOT:here's the baby bottle .",
#   '%mor:adv:loc|here~v:cop|be&3S det|the n|baby n|bottle .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:now give .', '%mor:adv|now v|give .'],
#  ['*MOT:you gotta burp the baby .',
#   '%mor:pro|you v|get&PAST~inf|to v|burp det|the n|baby .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:oh my goodness that baby burps so crazy .',
#   '%mor:co|oh pro:poss:det|my n|good&dadj-NESS det|that n|baby v|burp-3S'],
#  ['*MOT:now is the pillow all set ?',
#   '%mor:adv|now v:cop|be&3S det|the n|pillow adv:int|all adj|set ?'],
#  ['*MOT:is the blanket all nice ?',
#   '%mor:v:cop|be&3S det|the n|blanket adv:int|all adj|nice ?'],
#  ['*CHI:xxx .', '%mor:unk|xxx . '],
#  ['*MOT:mhm .', '%mor:co|yes .'],
#  ["*MOT:and what's that ?",
#   '%mor:coord|and pro:wh|what~v:cop|be&3S pro:dem|that ?'],
#  ['*MOT:is that a pillow ?', '%mor:v:cop|be&3S pro:dem|that det|a n|pillow ?'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*CHI:see .', '%mor:v|see .'],
#  ['*CHI:xxx need to be over here .',
#   '%mor:v|need inf|to v:cop|be prep|over adv:loc|here .'],
#  ['*CHI:the baby need to be right here .',
#   '%mor:det|the n|baby v|need inf|to v:cop|be adv|right adv:loc|here .'],
#  ['*CHI:and a blanket .', '%mor:coord|and det|a n|blanket .'],
#  ['*MOT:okay, very good .', '%mor:co|okay cm|cm adv:int|very adj|good .'],
#  ['%mor:unk|xxx . ', '*CHI:xxx .'],
#  ["*MOT:you're gonna be a very good daddy someday .",
#   '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v:cop|be det|a adv:int|very adj|good'],
#  ['*MOT:huh ?', '%mor:co|huh ?'],
#  ['*MOT:very nice .', '%mor:adv:int|very adj|nice .'],
#  ['*CHI:I think the baby is hungry .',
#   '%mor:pro:sub|I v|think det|the n|baby v:cop|be&3S adj|hungry .'],
#  ['*MOT:the baby just ate .', '%mor:det|the n|baby adv:int|just v|eat&PAST .'],
#  ['*MOT:and you just burped the baby .',
#   '%mor:coord|and pro|you adv:int|just v|burp-PAST det|the n|baby .'],
#  ['*MOT:the baby is hungry again ?', '%mor:unk|xxx . '],
#  ['%mor:det|the n|baby v:cop|be&3S adj|hungry adv|again ?', '*CHI:xxx .'],
#  ['*MOT:gulp gulp gulp .', '%mor:n|gulp n|gulp n|gulp .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*MOT:baby burped .', '%mor:n|baby v|burp-PAST .'],
#  ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .'],
#  ['*MOT:can you .', '%mor:aux|can pro|you .'],
#  ['*MOT:can you stack these blocks up ?',
#   '%mor:aux|can pro|you v|stack det|these n|block-PL prep|up ?'],
#  ['*MOT:with the biggest one on the bottom .',
#   '%mor:prep|with det|the adj|big-SP pro:indef|one prep|on det|the n|bottom .'],
#  ['*MOT:and the smallest one on the top .',
#   '%mor:coord|and det|the adj|small-SP pro:indef|one prep|on det|the n|top .'],
#  ['*CHI:oh .', '%mor:co|oh .'],
#  ['*MOT:biggest one on the bottom .',
#   '%mor:adj|big-SP pro:indef|one prep|on det|the n|bottom .'],
#  ['*MOT:oh, turn it upside down .',
#   '%mor:co|oh cm|cm v|turn pro|it adv|upside adv:loc|down .'],
#  ['*MOT:so we can stack them up .',
#   '%mor:conj|so pro:sub|we aux|can v|stack pro:obj|them adv:loc|up .'],
#  ['*MOT:there you go .', '%mor:adv:loc|there pro|you v|go .'],
#  ['*MOT:big .', '%mor:adj|big .'],
#  ['*MOT:smaller .', '%mor:adj|small-CP .'],
#  ['*MOT:smaller .', '%mor:adj|small-CP .'],
#  ['*MOT:and smallest .', '%mor:coord|and adj|small-SP .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:you did a great job .',
#   '%mor:pro|you v|do&PAST det|a adj|great n|job .'],
#  ['*MOT:what else can you put on top ?',
#   '%mor:pro:wh|what post|else aux|can pro|you v|put&ZERO prep|on n|top ?'],
#  ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .'],
#  ['*MOT:blocks .', '%mor:n|block-PL .'],
#  ['*MOT:blocks .', '%mor:n|block-PL .'],
#  ['*MOT:another block ?', '%mor:qn|another n|block ?'],
#  ['*MOT:how many ?', '%mor:adv:wh|how qn|many ?'],
#  ['*MOT:three .', '%mor:det:num|three .'],
#  ['*MOT:four .', '%mor:det:num|four .'],
#  ['*MOT:five .', '%mor:det:num|five .'],
#  ['*MOT:six .', '%mor:det:num|six .'],
#  ['*MOT:woah .', '%mor:int|woah .'],
#  ['*MOT:seven .', '%mor:det:num|seven .'],
#  ['*MOT:eight .', '%mor:det:num|eight .'],
#  ["*MOT:there's one right in front of you too .",
#   '%mor:adv:loc|there~v:cop|be&3S pro:indef|one adv|right prep|in n|front prep|of'],
#  ['*MOT:nine .', '%mor:det:num|nine .'],
#  ['*CHI:but this xxx .', '%mor:conj|but det|this .'],
#  ['*MOT:woah .', '%mor:int|woah .'],
#  ['*MOT:ahh .', '%mor:co|ahh .'],
#  ['*MOT:timber !', '%mor:n|timber !'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ['*MOT:are you gonna make the car run over the teddy_bear ?',
#   '%mor:aux|be&PRES pro|you v|go-PROG~inf|to v|make det|the n|car v|run prep|over'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*MOT:woah .', '%mor:int|woah .'],
#  ['*MOT:poor teddy_bear .', '%mor:adj|poor n|teddy_bear .'],
#  ['*MOT:teddy_bear can sit on top .',
#   '%mor:n|teddy_bear aux|can v|sit prep|on n|top .'],
#  ['*MOT:holy cow !', '%mor:adj|holy n|cow !'],
#  ['*MOT:oh wow .', '%mor:co|oh co|wow .'],
#  ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .'],
#  ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .'],
#  ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .'],
#  ['*MOT:gonna hit the octopus .',
#   '%mor:v|go-PROG~inf|to v|hit&ZERO det|the n|octopus .'],
#  ['*MOT:oh no .', '%mor:co|oh co|no .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*MOT:the poor octopus .', '%mor:det|the adj|poor n|octopus .'],
#  ["*MOT:here, let's make .", '%mor:adv:loc|here cm|cm v|let~pro|us v|make .'],
#  ['*MOT:I know what we can do .',
#   '%mor:pro:sub|I v|know pro:wh|what pro:sub|we aux|can v|do .'],
#  ['*MOT:wait, ready ?', '%mor:co|wait cm|cm adj|ready ?'],
#  ['*MOT:you gonna make the .',
#   '%mor:pro|you v|go-PROG~inf|to v|make det|the .'],
#  ["*INV1:you're so silly .",
#   '%mor:pro|you~v:cop|be&PRES adv:int|so adj|silly .'],
#  ['*MOT:come here Lester .', '%mor:v|come adv:loc|here n:prop|Lester .'],
#  ['*MOT:make the car come this way .',
#   '%mor:v|make det|the n|car v|come det|this n|way .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['%mor:unk|xxx . ', '*MOT:make the car and teddy_bear come this way .'],
#  ['%mor:v|make det|the n|car coord|and n|teddy_bear v|come det|this n|way .',
#   '*CHI:xxx .'],
#  ['*INV1:you gonna set her up ?',
#   '%mor:pro|you v|go-PROG~inf|to v|set&ZERO pro:obj|her prep|up ?'],
#  ['*MOT:oh no .', '%mor:co|oh co|no .'],
#  ['*MOT:the teddy_bear fell off .',
#   '%mor:det|the n|teddy_bear v|fall&PAST adv|off .'],
#  ['*MOT:okay, back up .', '%mor:co|okay cm|cm v|back prep|up .'],
#  ['*MOT:come over here buddy .',
#   '%mor:v|come prep|over adv:loc|here n|buddy .'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:wait, can I see that car ?',
#   '%mor:co|wait cm|cm aux|can pro:sub|I v|see det|that n|car ?'],
#  ["*MOT:oh, you're gonna play with the bus now ?",
#   '%mor:co|oh cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|play prep|with det|the'],
#  ['*CHI:no, I need to make the driver stand up .',
#   '%mor:co|no cm|cm pro:sub|I v|need inf|to v|make det|the n|drive&dv-AGT v|stand'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*CHI:now you can be that .',
#   '%mor:adv|now pro|you aux|can v:cop|be pro:dem|that .'],
#  ["*MOT:okay, I'll be the car .",
#   '%mor:co|okay cm|cm pro:sub|I~mod|will v:cop|be det|the n|car .'],
#  ['*MOT:alright, you be the bus .',
#   '%mor:co|alright cm|cm pro|you v:cop|be det|the n|bus .'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*CHI:I need .', '%mor:pro:sub|I v|need .'],
#  ['*CHI:I need .', '%mor:pro:sub|I v|need .'],
#  ['*CHI:I need to stack this up .',
#   '%mor:pro:sub|I v|need inf|to v|stack pro:dem|this adv:loc|up .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:stack up all the blocks up .',
#   '%mor:n|stack prep|up qn|all det|the n|block-PL prep|up .'],
#  ["*MOT:that's a good idea .",
#   '%mor:pro:dem|that~v:cop|be&3S det|a adj|good n|idea .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:okay, good .', '%mor:co|okay cm|cm adj|good .'],
#  ['*CHI:make a xxx .', '%mor:v|make det|a .'],
#  ['*CHI:drive over this .', '%mor:v|drive prep|over det|this .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ["*CHI:then it's xxx .", '%mor:adv:tem|then pro|it~aux|be&3S .'],
#  ["*MOT:wow, you're gonna make that really tall .",
#   '%mor:co|wow cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|make'],
#  ["*MOT:aren't you ?", '%mor:aux|be&PRES~neg|not pro|you ?'],
#  ['*MOT:how many are you using ?',
#   '%mor:adv:wh|how qn|many aux|be&PRES pro|you v|use-PROG ?'],
#  ['*CHI:one two three four five six seven eight .',
#   '%mor:det:num|one det:num|two det:num|three det:num|four det:num|five det:num|six'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*CHI:now .', '%mor:adv|now .'],
#  ['*CHI:where the control is .',
#   '%mor:rel|where det|the n|control v:cop|be&3S .'],
#  ['*CHI:knock it down !', '%mor:v|knock pro|it adv:loc|down !'],
#  ['*CHI:ahh .', '%mor:co|ahh .'],
#  ['*CHI:make that school bus knock down .',
#   '%mor:v|make det|that n|school n|bus n|knock adv:loc|down .'],
#  ['*MOT:oh, the octopus xxx on the .',
#   '%mor:co|oh cm|cm det|the n|octopus prep|on det|the .'],
#  ['*MOT:your turn .', '%mor:pro:poss:det|your n|turn .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*MOT:now what are you gonna do ?',
#   '%mor:adv|now pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do ?'],
#  ['*CHI:build something .', '%mor:v|build pro:indef|something .'],
#  ['*MOT:what are you gonna build ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|build ?'],
#  ['*CHI:a big tower .', '%mor:det|a adj|big n|tower .'],
#  ['*MOT:a big tower ?', '%mor:det|a adj|big n|tower ?'],
#  ["*MOT:oh that's really cool .",
#   '%mor:co|oh pro:dem|that~v:cop|be&3S adv:int|really adj|cool .'],
#  ['*MOT:look at this .', '%mor:v|look prep|at pro:dem|this .'],
#  ["*MOT:this lady's got a wheelchair .",
#   '%mor:det|this n|lady~aux|be&3S part|get&PERF det|a n|+n|wheel+n|chair .'],
#  ["*MOT:isn't that cool ?",
#   '%mor:v:cop|be&3S~neg|not pro:dem|that adj|cool ?'],
#  ['*CHI:I could knock him down .',
#   '%mor:pro:sub|I aux|could v|knock pro:obj|him adv:loc|down .'],
#  ['*MOT:no .', '%mor:co|no .'],
#  ['*MOT:we do not knock over people in wheelchairs .',
#   '%mor:pro:sub|we aux|do neg|not v|knock prep|over n|person&PL prep|in n|+n|wheel+n|chair-PL'],
#  ["*MOT:that's .", '%mor:pro:dem|that~v:cop|be&3S .'],
#  ["*MOT:that's how they got that way sometimes .",
#   '%mor:pro:dem|that~v:cop|be&3S adv:wh|how pro:sub|they v|get&PAST det|that n|way'],
#  ["*MOT:definitely don't need to do that huh .",
#   '%mor:adv|definite&dadj-LY aux|do~neg|not v|need inf|to v|do pro:dem|that'],
#  ['*CHI:okay .', '%mor:unk|xxx . '],
#  ['%mor:co|okay .', "*MOT:that's not nice ."],
#  ['%mor:pro:dem|that~v:cop|be&3S neg|not adj|nice .', '*CHI:xxx .'],
#  ['%mor:unk|xxx . ', '*CHI:um .'],
#  ['%mor:co|um .', '*CHI:car .'],
#  ['%mor:n|car .', '*CHI:xxx .'],
#  ['*MOT:that was a car accident .',
#   '%mor:pro:dem|that v:cop|be&PAST&13S det|a n|car n|accident .'],
#  ["*MOT:that's not good .",
#   '%mor:pro:dem|that~v:cop|be&3S neg|not adj|good .'],
#  ['*CHI:where the policeman ?',
#   '%mor:adv:wh|where det|the n|+n|police+n|man ?'],
#  ['*CHI:where the policeman ?',
#   '%mor:adv:wh|where det|the n|+n|police+n|man ?'],
#  ['*MOT:hmm .', '%mor:co|hmm .'],
#  ['*MOT:where is the policeman ?',
#   '%mor:adv:wh|where v:cop|be&3S det|the n|+n|police+n|man ?'],
#  ["*CHI:I think he's in there .",
#   '%mor:pro:sub|I v|think pro:sub|he~v:cop|be&3S prep|in adv:loc|there .'],
#  ['*MOT:maybe here .', '%mor:adv|maybe adv:loc|here .'],
#  ['*MOT:no no no .', '%mor:co|no co|no co|no .'],
#  ['*MOT:get out of there .', '%mor:v|get prep|out prep|of adv:loc|there .'],
#  ['*MOT:hey !', '%mor:co|hey !'],
#  ['*CHI:xxx policeman not there .',
#   '%mor:n|+n|police+n|man neg|not adv:loc|there .'],
#  ['*MOT:how about you use this as the policeman ?',
#   '%mor:adv:wh|how prep|about pro|you v|use'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ["*CHI:okay, but where's his car ?",
#   '%mor:co|okay cm|cm conj|but adv:wh|where~mod|do&3S pro:poss:det|his n|car ?'],
#  ["*CHI:where's his car ?",
#   '%mor:adv:wh|where~v:cop|be&3S pro:poss:det|his n|car ?'],
#  ["*MOT:we'll play with the car in a little bit and the policeman car .",
#   '%mor:pro:sub|we~mod|will v|play prep|with det|the n|car prep|in det|a adj|little'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ["*MOT:let's see how big of a tower we can build .",
#   '%mor:v|let~pro|us v|see adv:wh|how adj|big prep|of det|a n|tower'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ['*CHI:xxx we can use the car to knock it down .',
#   '%mor:pro:sub|we aux|can v|use det|the n|car inf|to v|knock pro|it adv:loc|down'],
#  ['*MOT:yeah, alright .', '%mor:co|yeah cm|cm adj|alright .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:first .', '%mor:adv|first .'],
#  ['*MOT:we have to build it up .',
#   '%mor:pro:sub|we v|have inf|to v|build pro|it adv:loc|up .'],
#  ['*CHI:I want it to be xxx .',
#   '%mor:pro:sub|I v|want pro|it inf|to v:cop|be .'],
#  ['*MOT:alright, put it behind you .',
#   '%mor:co|alright cm|cm v|put&ZERO pro|it prep|behind pro|you .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:now .', '%mor:adv|now .'],
#  ["*MOT:let's take all the blocks .",
#   '%mor:v|let~pro|us v|take qn|all det|the n|block-PL .'],
#  ["*MOT:let's build it way up .",
#   '%mor:v|let~pro|us v|build pro|it adv|way prep|up .'],
#  ["*CHI:hold on, we need to put them in here so we don't lose them .",
#   '%mor:v|hold adv|on cm|cm pro:sub|we v|need inf|to v|put&ZERO pro:obj|them prep|in'],
#  ['*CHI:then we can .', '%mor:adv:tem|then pro:sub|we aux|can .'],
#  ['*CHI:we can put them .',
#   '%mor:pro:sub|we aux|can v|put&ZERO pro:obj|them .'],
#  ['*CHI:we can build .', '%mor:pro:sub|we aux|can v|build .'],
#  ['*MOT:then we can drive it over here and build it up .',
#   '%mor:adv:tem|then pro:sub|we aux|can v|drive pro|it prep|over adv:loc|here'],
#  ['*CHI:yup .', '%mor:co|yup .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*MOT:now drive it over here .',
#   '%mor:adv|now v|drive pro|it prep|over adv:loc|here .'],
#  ['*CHI:beep beep beep beep .', '%mor:n|beep n|beep n|beep n|beep .'],
#  ['*MOT:alright .', '%mor:unk|xxx . '],
#  ['%mor:unk|xxx . ', '%mor:co|alright .'],
#  ['*MOT:now unload all the blocks .',
#   '%mor:adv|now un#v|load qn|all det|the n|block-PL .'],
#  ['*CHI:okay !', '%mor:co|okay !'],
#  ['*CHI:xxx .', '*CHI:xxx .'],
#  ["*MOT:there's another one .",
#   '%mor:adv:loc|there~v:cop|be&3S qn|another pro:indef|one .'],
#  ['*MOT:alright Sam, thanks so much .',
#   '%mor:co|alright n:prop|Sam cm|cm v|thank-3S adv:int|so qn|much .'],
#  ["*CHI:there's three more .",
#   '%mor:adv:loc|there~v:cop|be&3S det:num|three adv|more .'],
#  ['*MOT:thank you guy .', '%mor:v|thank pro|you n|guy .'],
#  ['*CHI:one more .', '%mor:det:num|one qn|more .'],
#  ["*MOT:you're a good guy .",
#   '%mor:pro|you~v:cop|be&PRES det|a adj|good n|guy .'],
#  ["*MOT:okay, now let's build them all up .",
#   '%mor:co|okay cm|cm adv|now v|let~pro|us v|build pro:obj|them qn|all'],
#  ['*MOT:xxx up the truck and get it out of the way .',
#   '%mor:prep|up det|the n|truck coord|and v|get pro|it n|out prep|of det|the n|way'],
#  ['*MOT:okay, move that truck out of the way .',
#   '%mor:co|okay cm|cm v|move det|that v|truck prep|out prep|of det|the n|way'],
#  ['*MOT:okay come back over here .',
#   '%mor:co|okay v|come n|back prep|over adv:loc|here .'],
#  ['*MOT:okay, ready ?', '%mor:co|okay cm|cm adj|ready ?'],
#  ['*MOT:time to build up the block tower .',
#   '%mor:n|time inf|to v|build prep|up det|the n|block n|tower .'],
#  ['*CHI:yup .', '%mor:co|yup .'],
#  ['*MOT:then we can knock it down .',
#   '%mor:adv:tem|then pro:sub|we aux|can v|knock pro|it adv:loc|down .'],
#  ['*CHI:you can .', '%mor:pro|you aux|can .'],
#  ['*MOT:but we have to build it up first .',
#   '%mor:conj|but pro:sub|we v|have inf|to v|build pro|it adv:loc|up adj|first'],
#  ['*MOT:I need you to help me .',
#   '%mor:pro:sub|I v|need pro|you inf|to v|help pro:obj|me .'],
#  ['*MOT:ready ?', '%mor:adj|ready ?'],
#  ["*MOT:let's do one .", '%mor:v|let~pro|us v|do pro:indef|one .'],
#  ['*MOT:can you sit over here please ?',
#   '%mor:aux|can pro|you v|sit prep|over adv:loc|here v|please ?'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*MOT:sit over here .', '%mor:v|sit adv:loc|over adv:loc|here .'],
#  ['*MOT:thank you .', '%mor:v|thank pro|you .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:one two .', '%mor:det:num|one det:num|two .'],
#  ['*MOT:three four .', '%mor:det:num|three det:num|four .'],
#  ['*MOT:five six .', '%mor:det:num|five det:num|six .'],
#  ["*MOT:what's this one ?",
#   '%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?'],
#  ['*CHI:a train .', '%mor:det|a n|train .'],
#  ['*MOT:no, what number ?', '%mor:co|no cm|cm pro:wh|what n|number ?'],
#  ['*MOT:one two three four five six seven .',
#   '%mor:det:num|one det:num|two det:num|three det:num|four det:num|five det:num|six'],
#  ['*CHI:seven .', '%mor:det:num|seven .'],
#  ['*MOT:eight .', '%mor:det:num|eight .'],
#  ['*CHI:eight .', '%mor:det:num|eight .'],
#  ['*CHI:eight .', '%mor:det:num|eight .'],
#  ["*MOT:what's this one ?",
#   '%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?'],
#  ['*CHI:ten .', '%mor:det:num|ten .'],
#  ['*MOT:nine .', '%mor:det:num|nine .'],
#  ['*MOT:stop .', '%mor:n|stop .'],
#  ['*CHI:nine .', '%mor:det:num|nine .'],
#  ['*MOT:ten .', '%mor:det:num|ten .'],
#  ['*MOT:what comes after nine ?',
#   '%mor:pro:wh|what v|come-3S prep|after det:num|nine ?'],
#  ['*CHI:ten eleven twelve thirteen .',
#   '%mor:det:num|ten det:num|eleven det:num|twelve det:num|thirteen .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:okay ready ?', '%mor:co|okay adj|ready ?'],
#  ['*MOT:you gonna knock it down .',
#   '%mor:pro|you v|go-PROG~inf|to v|knock pro|it adv:loc|down .'],
#  ['*MOT:ready ?', '%mor:adj|ready ?'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*CHI:here comes the car .', '%mor:adv:loc|here v|come-3S det|the n|car .'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ["*MOT:now I'm gonna build one .",
#   '%mor:adv|now pro:sub|I~aux|be&1S v|go-PROG~inf|to v|build pro:indef|one .'],
#  ['*MOT:okay, ready ?', '%mor:co|okay cm|cm adj|ready ?'],
#  ["*MOT:we'll look at some books right now buddy .",
#   '%mor:pro:sub|we~mod|will v|look prep|at qn|some n|book-PL adv|right adv|now'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*MOT:yes .', '%mor:co|yes .'],
#  ["*CHI:let's look at some books .",
#   '%mor:v|let~pro|us n|look prep|at qn|some n|book-PL .'],
#  ["*MOT:we'll come back to the car okay .",
#   '%mor:pro:sub|we~mod|will v|come n|back prep|to det|the n|car adj|okay .'],
#  ["*MOT:we're gonna come back to the car when we're done .",
#   '%mor:pro:sub|we~v:cop|be&PRES v|go-PROG~inf|to v|come n|back prep|to det|the'],
#  ['*MOT:first we have to play with the books .',
#   '%mor:adv|first pro:sub|we v|have inf|to v|play prep|with det|the n|book-PL'],
#  ['*CHI:I did not want .', '%mor:pro:sub|I aux|do&PAST neg|not v|want .'],
#  ["*CHI:I don't want to read the books .",
#   '%mor:pro:sub|I aux|do~neg|not v|want inf|to v|read&ZERO det|the n|book-PL .'],
#  ['*MOT:just for one minute .',
#   '%mor:adj|just prep|for pro:indef|one n|minute .'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*MOT:yes .', '%mor:co|yes .'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*MOT:do you want to play with the car again ?',
#   '%mor:aux|do pro|you v|want inf|to v|play prep|with det|the n|car adv|again'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*CHI:I want to knock the tower down .',
#   '%mor:pro:sub|I v|want inf|to v|knock det|the n|tower adv:loc|down .'],
#  ["*MOT:okay, we can do that as soon as we're done with the books .",
#   '%mor:co|okay cm|cm pro:sub|we aux|can aux|do adv:int|that adv|as adv|soon adv|as'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ['%mor:unk|xxx . ', '*MOT:okay ?'],
#  ['%mor:co|okay ?', '*CHI:okay .'],
#  ['%mor:co|okay .', '%mor:unk|xxx . '],
#  ["*MOT:come on over and as soon as we're done with the books .",
#   '%mor:v|come adv|on prep|over coord|and conj|as adj|soon adv|as pro:sub|we~aux|be&PRES'],
#  ['*CHI:xxx .', '*CHI:here .'],
#  ['%mor:adv:loc|here .', '*CHI:xxx there .'],
#  ['%mor:adv:loc|there .', '*CHI:xxx .'],
#  ["*MOT:I don't mean play with them .",
#   '%mor:pro:sub|I aux|do~neg|not adj|mean v|play prep|with pro:obj|them .'],
#  ['*MOT:we have to read them .',
#   '%mor:pro:sub|we v|have inf|to v|read&ZERO pro:obj|them .'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ['*MOT:which book do you want to read ?',
#   '%mor:rel|which n|book aux|do pro|you v|want inf|to v|read&ZERO ?'],
#  ['*MOT:which book do you want to read ?',
#   '%mor:rel|which n|book aux|do pro|you v|want inf|to v|read&ZERO ?'],
#  ['*CHI:I xxx one .', '%mor:unk|xxx . '],
#  ['%mor:pro:sub|I pro:indef|one .', '*MOT:which one ?'],
#  ['%mor:rel|which pro:indef|one ?', '*MOT:this one ?'],
#  ['%mor:det|this pro:indef|one ?', '*MOT:this one .'],
#  ['%mor:det|this pro:indef|one .', '*MOT:which one ?'],
#  ['%mor:rel|which pro:indef|one ?', '*CHI:xxx .'],
#  ['*MOT:wanna read this one ?',
#   '%mor:v|want~inf|to v|read&ZERO det|this pro:indef|one ?'],
#  ['*MOT:"How many are there ?"',
#   '%mor:?|"How qn|many v:cop|be&PRES adv:loc|there ?|?"'],
#  ['*MOT:this one .', '%mor:det|this pro:indef|one .'],
#  ['*MOT:+" Wiggle_Jiggle Jump_Up+".',
#   '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up+".'],
#  ['*CHI:yup .', '%mor:co|yup .'],
#  ['*MOT:okay, come here .', '%mor:co|okay cm|cm v|come adv:loc|here .'],
#  ['*MOT:come sit on my lap .',
#   '%mor:v|come v|sit prep|on pro:poss:det|my n|lap .'],
#  ['*MOT:come on .', '%mor:v|come adv:loc|on .'],
#  ['*CHI:but he wants to .', '%mor:conj|but pro:sub|he v|want-3S prep|to .'],
#  ['*CHI:he wants to read too .',
#   '%mor:pro:sub|he v|want-3S inf|to v|read&ZERO adv:int|too .'],
#  ['*MOT:oh great .', '%mor:co|oh adj|great .'],
#  ["*MOT:that's great .", '%mor:pro:dem|that~v:cop|be&3S adj|great .'],
#  ['*MOT:come on over here .', '%mor:v|come prep|on prep|over adv:loc|here .'],
#  ['*MOT:perfect .', '%mor:adj|perfect .'],
#  ['*MOT:come sit on my lap and then we can all read together .',
#   '%mor:v|come v|sit prep|on pro:poss:det|my n|lap coord|and adv:tem|then pro:sub|we'],
#  ['*MOT:okay ?', '%mor:co|okay ?'],
#  ['*MOT:come sit on my lap .',
#   '%mor:v|come v|sit prep|on pro:poss:det|my n|lap .'],
#  ['*MOT:come on .', '%mor:v|come adv:loc|on .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['%mor:unk|xxx . ', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:+" Wiggle+".'],
#  ['%mor:n:prop|Wiggle+".', '*MOT:ready ?'],
#  ['%mor:adj|ready ?', '*MOT:Lester .'],
#  ['%mor:n:prop|Lester .', '*MOT:+" Wiggle_Jiggle Jump_Up+".'],
#  ['%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up+".', '*CHI:xxx .'],
#  ['*MOT:Lester .', '%mor:n:prop|Lester .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ["*MOT:where's the dinosaur ?",
#   '%mor:adv:wh|where~v:cop|be&3S det|the n|dinosaur ?'],
#  ['*MOT:and who is this ?', '%mor:coord|and rel|who v:cop|be&3S det|this ?'],
#  ['*CHI:a bear .', '%mor:det|a n|bear .'],
#  ['*MOT:a bear .', '%mor:det|a n|bear .'],
#  ["*MOT:what's his name ?",
#   '%mor:pro:wh|what~v:cop|be&3S pro:poss:det|his n|name ?'],
#  ['*MOT:+" Jesse Bear\'s Wiggle_Jiggle Jump_Up +".',
#   '%mor:n:prop|Jesse n:prop|Bear~poss|s n:prop|Wiggle_Jiggle n:prop|Jump_Up +".'],
#  ["*MOT:what's his name ?",
#   '%mor:pro:wh|what~v:cop|be&3S pro:poss:det|his n|name ?'],
#  ['*CHI:Wiggle_Jiggle Jump_Up .',
#   '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up .'],
#  ['*MOT:+" Jesse Bear\'s Wiggle_Jiggle Jump_Up +".',
#   '%mor:n:prop|Jesse n:prop|Bear~poss|s n:prop|Wiggle_Jiggle n:prop|Jump_Up +".'],
#  ['*MOT:ready ?', '%mor:adj|ready ?'],
#  ['*MOT:you gonna turn the page with me ?',
#   '%mor:pro|you v|go-PROG~inf|to v|turn det|the n|page prep|with pro:obj|me ?'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*MOT:+" Wiggle_Jiggle Jump_Up silly_willy prance +".',
#   '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up ?|silly_willy v|prance +".'],
#  ['*MOT:what is he doing ?',
#   '%mor:pro:wh|what v:cop|be&3S pro:sub|he part|do-PROG ?'],
#  ["*CHI:he's jumping on the bed .",
#   '%mor:pro:sub|he~aux|be&3S part|jump-PROG prep|on det|the n|bed .'],
#  ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .'],
#  ['*MOT:what happened with this clothes ?',
#   '%mor:pro:wh|what v|happen-PAST prep|with det|this n:pt|clothes ?'],
#  ['*CHI:he .', '%mor:pro:sub|he .'],
#  ['*CHI:it just fall off .', '%mor:pro|it adv:int|just v|fall adv|off .'],
#  ['*MOT:he jumped right off of them xxx .',
#   '%mor:pro:sub|he v|jump-PAST adv|right prep|off prep|of pro:obj|them .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:and what about his dinosaur ?',
#   '%mor:coord|and pro:wh|what prep|about pro:poss:det|his n|dinosaur ?'],
#  ['*CHI:wait, wait .', '%mor:co|wait cm|cm v|wait .'],
#  ['*MOT:wait .', '%mor:co|wait .'],
#  ['*MOT:oh fishie wants to watch too ?',
#   '%mor:co|oh n|fish-DIM v|want-3S inf|to n|watch adv:int|too ?'],
#  ['*CHI:and all of these .',
#   '%mor:coord|and pro:indef|all prep|of det|these .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*CHI:all of them need to watch .',
#   '%mor:pro:indef|all prep|of pro:obj|them v|need inf|to v|watch .'],
#  ["*MOT:everybody's watching .",
#   '%mor:pro:indef|everybody~aux|be&3S part|watch-PROG .'],
#  ["*MOT:that's great .", '%mor:pro:dem|that~v:cop|be&3S adj|great .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*CHI:I can watch too .', '%mor:pro:sub|I aux|can n|watch adv:int|too .'],
#  ["*MOT:baby's sleeping .", '%mor:n|baby~aux|be&3S part|sleep-PROG .'],
#  ['*MOT:you ready ?', '%mor:pro|you v|ready ?'],
#  ["*MOT:let's turn the page .", '%mor:v|let~pro|us v|turn det|the n|page .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*MOT:+" button up the shirt +".',
#   '%mor:n|button prep|up det|the n|shirt +".'],
#  ['*MOT:who ?', '%mor:rel|who ?'],
#  ['*MOT:where ?', '%mor:adv:wh|where ?'],
#  ["*MOT:which picture's got him buttoning up his shirt ?",
#   '%mor:rel|which v|picture~v|have&3S v|get&PAST pro:obj|him adj:part|button-PROG'],
#  ["*MOT:who's buttoning up his shirt ?",
#   '%mor:rel|who~aux|be&3S part|button-PROG prep|up pro:poss:det|his n|shirt ?'],
#  ['*CHI:uhm, his dad .', '%mor:?|uhm cm|cm pro:poss:det|his n|dad .'],
#  ['*MOT:his daddy .', '%mor:pro:poss:det|his n|daddy .'],
#  ['*MOT:yeah .', '%mor:co|yeah .'],
#  ['*MOT:look here Lester .', '%mor:n|look adv:loc|here n:prop|Lester .'],
#  ['*MOT:+"put on the pants+".', '%mor:+"put prep|on det|the ?|pants+".'],
#  ['*CHI:put on the pants .', '%mor:v|put&ZERO prep|on det|the n:pt|pants .'],
#  ['*MOT:xxx .', '*MOT:wears his shoes .'],
#  ['%mor:v|wear-3S pro:poss:det|his n|shoe-PL .', '*CHI:wears his shoes .'],
#  ['%mor:v|wear-3S pro:poss:det|his n|shoe-PL .',
#   '*MOT:is he doing a good job putting on his pants ?'],
#  ['%mor:v:cop|be&3S pro:sub|he part|do-PROG det|a adj|good n|job adj:part|put-PROG',
#   '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*MOT:yeah .'],
#  ['%mor:co|yeah .', "*CHI:and he's jumping up xxx ."],
#  ['%mor:coord|and pro:sub|he~aux|be&3S part|jump-PROG adv:loc|up .',
#   '*MOT:look at this picture .'],
#  ['%mor:n|look prep|at det|this n|picture .',
#   "*MOT:he's still just wearing his underwear ."],
#  ['%mor:pro:sub|he~aux|be&3S adv|still adv:int|just part|wear-PROG pro:poss:det|his',
#   "*MOT:isn't that silly ?"],
#  ['%mor:v:cop|be&3S~neg|not pro:dem|that adj|silly ?',
#   '*MOT:+" pull on the socks +".'],
#  ['%mor:v|pull prep|on det|the n|sock-PL +".', '*MOT:+" tie up the shoes +".'],
#  ['%mor:n|tie prep|up det|the n|shoe-PL +".',
#   '*MOT:do you put on your own socks ?'],
#  ['%mor:aux|do pro|you v|put&ZERO prep|on pro:poss:det|your adj|own n|sock-PL',
#   '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*CHI:and shoes .'],
#  ['%mor:coord|and n|shoe-PL .', '*MOT:and shoes just like Jesse bear .'],
#  ['%mor:coord|and n|shoe-PL adv:int|just rel|like n:prop|Jesse n|bear .',
#   '*CHI:hold on, I need to brush his hair .'],
#  ['%mor:v|hold adv|on cm|cm pro:sub|I v|need inf|to v|brush pro:poss:det|his n|hair',
#   '*MOT:come here .'],
#  ['%mor:v|come adv:loc|here .', "*MOT:we're not done with this book yet ."],
#  ['%mor:unk|xxx . ',
#   '%mor:pro:sub|we~v:cop|be&PRES neg|not adj|done prep|with det|this n|book adv|yet'],
#  ['*CHI:I need to .', '%mor:pro:sub|I v|need prep|to .'],
#  ["*MOT:we can do that as soon as we're done .",
#   '%mor:pro:sub|we aux|can aux|do adv:int|that adv|as adv|soon adv|as pro:sub|we~aux|be&PRES'],
#  ["*CHI:I need to brush the baby's hair .",
#   '%mor:pro:sub|I v|need inf|to v|brush det|the n|baby~poss|s n|hair .'],
#  ['*MOT:not yet Lester .', '%mor:neg|not adv|yet n:prop|Lester .'],
#  ['*CHI:xxx .', '*MOT:Lester .'],
#  ['%mor:n:prop|Lester .', '*CHI:I just wanted the brush .'],
#  ['%mor:pro:sub|I adv:int|just v|want-PAST det|the n|brush .',
#   '*MOT:oh you wanna hold the brush ?'],
#  ['%mor:co|oh pro|you v|want~inf|to v|hold det|the n|brush ?',
#   "*MOT:where's the mommy bear ?"],
#  ['%mor:adv:wh|where~v:cop|be&3S det|the n|mommy n|bear ?',
#   "*MOT:and where's daddy bear ?"],
#  ['%mor:coord|and rel|where~aux|be&3S adj|dad&dn-Y n|bear ?',
#   '*CHI:uhm, xxx .'],
#  ['%mor:?|uhm cm|cm .',
#   "*MOT:what's daddy bear wearing on the front of himself ?"],
#  ['%mor:pro:wh|what~aux|be&3S n|daddy n|bear adj:part|wear-PROG prep|on det|the',
#   '*CHI:his tie .'],
#  ['%mor:pro:poss:det|his n|tie .', '*MOT:his tie .'],
#  ['%mor:pro:poss:det|his n|tie .', "*MOT:what's on his tie ?"],
#  ['%mor:pro:wh|what~v:cop|be&3S prep|on pro:poss:det|his n|tie ?',
#   '*CHI:bumblebees and honey .'],
#  ['%mor:n|+n|bumble+n|bee-PL coord|and n|honey .',
#   '*MOT:bumblebees and honey .'],
#  ['%mor:n|+n|bumble+n|bee-PL coord|and n|honey .', '*MOT:very good .'],
#  ['%mor:adv:int|very adj|good .', '*MOT:time to turn the page .'],
#  ['%mor:v|time inf|to v|turn det|the n|page .',
#   '*MOT:+" Jesse dance with me and I\'ll dance with you +".'],
#  ['%mor:n:prop|Jesse n|dance prep|with pro:obj|me coord|and pro:sub|I~mod|will',
#   "*MOT:who's dancing ?"],
#  ['%mor:rel|who~aux|be&3S part|dance-PROG ?', '*CHI:him him him .'],
#  ['%mor:pro:obj|him pro:obj|him pro:obj|him .', "*MOT:who's this ?"],
#  ['%mor:pro:wh|who~v:cop|be&3S pro:dem|this ?', '*CHI:the dad .'],
#  ['%mor:det|the n|dad .', "*MOT:and who's this ?"],
#  ['%mor:coord|and pro:wh|who~v:cop|be&3S pro:dem|this ?',
#   '*CHI:his brother .'],
#  ['%mor:pro:poss:det|his n|brother .', '*MOT:no .'],
#  ['%mor:co|no .', '*MOT:who is this ?'],
#  ['%mor:pro:wh|who v:cop|be&3S det|this ?', '*CHI:his xxx .'],
#  ['%mor:pro:poss:det|his .', '*MOT:look .'],
#  ['%mor:n|look .', '*MOT:Jesse .'],
#  ['%mor:n:prop|Jesse .', "*MOT:and who's this ?"],
#  ['%mor:coord|and pro:wh|who~v:cop|be&3S pro:dem|this ?', "*MOT:who's this ?"],
#  ['%mor:pro:wh|who~v:cop|be&3S pro:dem|this ?', '*CHI:uhm .'],
#  ['%mor:?|uhm .', '%mor:unk|xxx . '],
#  ["*CHI:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .'],
#  ["*MOT:you don't know who this is ?",
#   '%mor:pro|you aux|do~neg|not v|know pro:wh|who pro:dem|this v:cop|be&3S ?'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ["*MOT:that's the momma bear .",
#   '%mor:pro:dem|that~v:cop|be&3S det|the n|momma n|bear .'],
#  ['*CHI:hey leave it over there .',
#   '%mor:co|hey n|leave pro|it prep|over adv:loc|there .'],
#  ["*MOT:Lester you're not xxx .",
#   '%mor:n:prop|Lester pro|you~v:cop|be&PRES neg|not .'],
#  ['*CHI:xxx .', "*MOT:now we have to read another book cause you didn't ."],
#  ['%mor:adv|now pro:sub|we v|have inf|to v|read&ZERO qn|another n|book v|cause',
#   '*CHI:no .'],
#  ['%mor:co|no .', '*MOT:oh .'],
#  ['%mor:co|oh .', "*CHI:I don't want to read another book ."],
#  ['%mor:pro:sub|I aux|do~neg|not v|want inf|to v|read&ZERO qn|another n|book .',
#   '*MOT:Lester, look what I have in here .'],
#  ['%mor:n:prop|Lester cm|cm v|look pro:wh|what pro:sub|I v|have prep|in adv:loc|here',
#   '*MOT:you can have some .'],
#  ['%mor:pro|you aux|can v|have qn|some .', '*MOT:stay here with me .'],
#  ['%mor:v|stay adv:loc|here prep|with pro:obj|me .', '*MOT:oh .'],
#  ['%mor:co|oh .', '*INV1:just one .'],
#  ['%mor:adj|just pro:indef|one .', '*MOT:just one piece .'],
#  ['%mor:adv:int|just det:num|one n|piece .', '*MOT:one .'],
#  ['%mor:pro:indef|one .', '*MOT:which color are you going to pick ?'],
#  ['%mor:rel|which n|color aux|be&PRES pro|you part|go-PROG inf|to v|pick ?',
#   '*MOT:just one .'],
#  ['%mor:adj|just pro:indef|one .', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:now we have to put the top back on .'],
#  ['%mor:adv|now pro:sub|we v|have inf|to v|put&ZERO det|the n|top adv:loc|back',
#   '*CHI:I can do that .'],
#  ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:wait a second !'],
#  ['%mor:v|wait det|a n|second !', '*CHI:I can do that .'],
#  ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:let me see this .'],
#  ['%mor:v|let&ZERO pro:obj|me v|see det|this .', '*CHI:I can do that .'],
#  ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:wait .'],
#  ['%mor:co|wait .', '*MOT:just a minute .'],
#  ['%mor:adv:int|just det|a n|minute .', '*MOT:we have to follow directions .'],
#  ['%mor:pro:sub|we v|have inf|to v|follow n|direction-PL .',
#   '*CHI:I can do that .'],
#  ['%mor:pro:sub|I aux|can v|do pro:dem|that .',
#   '*MOT:you gonna put the top on ?'],
#  ['%mor:unk|xxx . ',
#   '%mor:pro|you v|go-PROG~inf|to v|put&ZERO det|the adj|top adv|on ?'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:put the top on .', '%mor:v|put&ZERO det|the adj|top adv|on .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:put it on .', '%mor:v|put&ZERO pro|it adv:loc|on .'],
#  ['*MOT:okay, now look what I have .',
#   '%mor:co|okay cm|cm adv|now v|look pro:wh|what pro:sub|I v|have .'],
#  ['*MOT:look what I have .', '%mor:v|look pro:wh|what pro:sub|I v|have .'],
#  ['*CHI:xxx .', '*MOT:which one do you want ?'],
#  ['%mor:rel|which pro:indef|one v|do pro|you v|want ?',
#   '*MOT:which one do you want ?'],
#  ['%mor:rel|which pro:indef|one v|do pro|you v|want ?', '*MOT:yeah ?'],
#  ['%mor:co|yeah ?', '%mor:unk|xxx . '],
#  ['*MOT:why do you want this one ?',
#   '%mor:adv:wh|why aux|do pro|you v|want det|this pro:indef|one ?'],
#  ['*CHI:because I want to put it in the school bus .',
#   '%mor:conj|because pro:sub|I v|want inf|to v|put&ZERO pro|it prep|in det|the'],
#  ['*MOT:because you want to put it in the school bus .',
#   '%mor:conj|because pro|you v|want inf|to v|put&ZERO pro|it prep|in det|the n|school'],
#  ['*MOT:do you want another piece ?',
#   '%mor:aux|do pro|you v|want qn|another n|piece ?'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*MOT:no .', '%mor:co|no .'],
#  ['*CHI:xxx .', '*MOT:do you want the empty one ?'],
#  ['%mor:v|do pro|you v|want det|the adj|empty pro:indef|one ?', '*CHI:sure .'],
#  ['%mor:adj|sure .', '*MOT:okay .'],
#  ['%mor:unk|xxx . ', '%mor:co|okay .'],
#  ['*CHI:xxx put in .', '%mor:v|put&ZERO adv:loc|in .'],
#  ['*MOT:what are you gonna do with that one ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with det|that'],
#  ['*CHI:maybe we can put in skittles .',
#   '%mor:adv|maybe pro:sub|we aux|can v|put&ZERO prep|in n|skittle-PL .'],
#  ['*MOT:maybe we can put in skittles .',
#   '%mor:adv|maybe pro:sub|we aux|can v|put&ZERO prep|in n|skittle-PL .'],
#  ['*MOT:put one in each one ?',
#   '%mor:v|put&ZERO pro:indef|one prep|in qn|each pro:indef|one ?'],
#  ['*MOT:ooh look at that .', '%mor:co|ooh v|look prep|at det|that .'],
#  ['*CHI:xxx .', '*MOT:look what I have now .'],
#  ['%mor:v|look pro:wh|what pro:sub|I aux|have adv|now .',
#   '*MOT:what is this ?'],
#  ['%mor:pro:wh|what v:cop|be&3S det|this ?', '*CHI:a balloon pumper .'],
#  ['%mor:det|a n|balloon n|pump&dv-AGT .', '*MOT:a balloon pumper .'],
#  ['%mor:det|a n|balloon n|pump&dv-AGT .', '*CHI:yeah, I want to try it .'],
#  ['%mor:co|yeah cm|cm pro:sub|I v|want inf|to v|try pro|it .', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:no, mommy first .'],
#  ['%mor:co|no cm|cm n|mommy adv|first .', "*MOT:I'm gonna do ."],
#  ['%mor:pro:sub|I~aux|be&1S v|go-PROG~inf|to v|do .',
#   "*MOT:look what I'm gonna do ."],
#  ['%mor:v|look pro:wh|what pro:sub|I~aux|be&1S v|go-PROG~inf|to v|do .',
#   '*MOT:ready ?'],
#  ['%mor:adj|ready ?', '*MOT:let mommy do it first .'],
#  ['%mor:v|let&ZERO n|mommy v|do pro|it adv|first .',
#   '*INV1:then you press the trigger after you .'],
#  ['%mor:adv:tem|then pro|you v|press det|the n|trigger prep|after pro|you .',
#   '*MOT:oh .'],
#  ['%mor:co|oh .', '*INV1:pump it .'],
#  ['%mor:v|pump pro|it .', '*INV2:yeah, then it blows by itself .'],
#  ['%mor:co|yeah cm|cm adv:tem|then pro|it v|blow-3S prep|by pro:refl|itself .',
#   '*MOT:oh .'],
#  ['%mor:co|oh .', '*MOT:cool .'],
#  ['%mor:adj|cool .', '*INV2:I discovered it recently .'],
#  ['%mor:pro:sub|I v|discover-PAST pro|it adv|recent&dadj-LY .',
#   '*CHI:woah, tie it .'],
#  ['%mor:int|woah cm|cm v|tie pro|it .', '*CHI:tie it .'],
#  ['%mor:v|tie pro|it .', '*MOT:okay, ready ?'],
#  ['%mor:co|okay cm|cm adj|ready ?', '*MOT:what am I gonna do ?'],
#  ['%mor:pro:wh|what v:cop|be&1S pro:sub|I v|go-PROG~inf|to v|do ?',
#   '*CHI:tie it .'],
#  ['%mor:v|tie pro|it .', "*MOT:where'd it go ?"],
#  ['%mor:rel|where~mod|genmod pro|it v|go ?', '*MOT:where did it go ?'],
#  ['%mor:adv:wh|where v|do&PAST pro|it v|go ?', '*MOT:over here .'],
#  ['%mor:prep|over adv:loc|here .', '*CHI:xxx over here .'],
#  ['%mor:prep|over adv:loc|here .', "*CHI:now it's my turn ."],
#  ['%mor:adv|now pro|it~v:cop|be&3S pro:poss:det|my n|turn .',
#   '*MOT:your turn .'],
#  ['%mor:pro:poss:det|your n|turn .', '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:so what do you do ?'],
#  ['%mor:co|so pro:wh|what aux|do pro|you v|do ?', '*CHI:can you hold it ?'],
#  ['%mor:aux|can pro|you v|hold pro|it ?', '*CHI:and I pump it .'],
#  ['%mor:coord|and pro:sub|I v|pump pro|it .', '*MOT:okay, ready ?'],
#  ['%mor:co|okay cm|cm adj|ready ?', '*CHI:do it .'],
#  ['%mor:v|do pro|it .', "*MOT:stop, don't pump ."],
#  ['%mor:n|stop cm|cm aux|do~neg|not n|pump .', '%mor:unk|xxx . '],
#  ['*MOT:you gotta wait till it fills .',
#   '%mor:pro|you v|get&PAST~inf|to co|wait v|till pro|it v|fill-3S .'],
#  ['*MOT:pump just a little bit more .',
#   '%mor:n|pump adv:int|just det|a adj|little n|bit qn|more .'],
#  ["*MOT:okay, that's it .",
#   '%mor:co|okay cm|cm pro:dem|that~v:cop|be&3S pro|it .'],
#  ["*CHI:it's a .", '%mor:pro|it~v:cop|be&3S det|a .'],
#  ["*CHI:it's a pear .", '%mor:pro|it~v:cop|be&3S det|a n|pear .'],
#  ['*MOT:it looks like a pear .',
#   '%mor:pro|it v|look-3S prep|like det|a n|pear .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*CHI:tie it .', '%mor:v|tie pro|it .'],
#  ['*CHI:xxx .', '*MOT:oh .'],
#  ['%mor:co|oh .', '*CHI:do you want a skittle ?'],
#  ['%mor:aux|do pro|you v|want det|a n|skittle ?', '*MOT:uh, no thanks .'],
#  ['%mor:co|uh cm|cm co|no co|thanks .',
#   '*MOT:thank you for asking, I appretiate it .'],
#  ['%mor:v|thank pro|you prep|for n:gerund|ask-PROG cm|cm pro:sub|I ?|appretiate',
#   '*INV1:do one more of the xxx .'],
#  ['%mor:v|do pro:indef|one qn|more prep|of det|the .', '*MOT:okay .'],
#  ['%mor:co|okay .', "*MOT:you're gonna hold it, okay ?"],
#  ['%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v|hold pro|it cm|cm adj|okay ?',
#   "*CHI:it's just like a balloon ."],
#  ['%mor:pro|it~v:cop|be&3S adv:int|just prep|like det|a n|balloon .',
#   '*MOT:it is a balloon .'],
#  ['%mor:pro|it v:cop|be&3S det|a n|balloon .',
#   "*MOT:it's not just like a balloon ."],
#  ['%mor:pro|it~v:cop|be&3S neg|not adv:int|just prep|like det|a n|balloon .',
#   '*MOT:it is a balloon .'],
#  ['%mor:unk|xxx . ', '%mor:pro|it v:cop|be&3S det|a n|balloon .'],
#  ['*CHI:can we tie it ?', '%mor:aux|can pro:sub|we v|tie pro|it ?'],
#  ['*CHI:can we tie it ?', '%mor:aux|can pro:sub|we v|tie pro|it ?'],
#  ["*MOT:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .'],
#  ["*MOT:there aren't our balloons .",
#   '%mor:adv:loc|there aux|be&PRES~neg|not pro:poss:det|our n|balloon-PL .'],
#  ['*CHI:can we tie this ?', '%mor:aux|can pro:sub|we v|tie det|this ?'],
#  ["*INV1:we'll do it at the end .",
#   '%mor:pro:sub|we~mod|will aux|do pro|it prep|at det|the n|end .'],
#  ["*MOT:how's that ?", '%mor:adv:wh|how~aux|be&3S pro:dem|that ?'],
#  ['*MOT:oh .', '%mor:unk|xxx . '],
#  ['%mor:co|oh .', '*CHI:xxx .'],
#  ['*MOT:alright, come sit down again .',
#   '%mor:co|alright cm|cm v|come v|sit adv:loc|down adv|again .'],
#  ['*CHI:got it .', '%mor:v|get&PAST pro|it .'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ['*MOT:here, let me hold on to this .',
#   '%mor:adv:loc|here cm|cm v|let&ZERO pro:obj|me v|hold prep|on prep|to pro:dem|this'],
#  ["*MOT:I'll hold on to this .",
#   '%mor:pro:sub|I~mod|will v|hold prep|on prep|to pro:dem|this .'],
#  ["*MOT:we'll do this when we're done .",
#   '%mor:pro:sub|we~mod|will v|do det|this conj|when pro:sub|we~aux|be&PRES adj|done'],
#  ["*CHI:I'll do it .", '%mor:pro:sub|I~mod|will aux|do pro|it .'],
#  ['*CHI:xxx .', "*MOT:when we're done ."],
#  ['%mor:conj|when pro:sub|we~v:cop|be&PRES adj|done .',
#   "*MOT:when we're done ."],
#  ['%mor:conj|when pro:sub|we~v:cop|be&PRES adj|done .', '*MOT:first .'],
#  ['%mor:adv|first .', '*MOT:look Lester, look what I have now .'],
#  ['%mor:v|look n:prop|Lester cm|cm v|look pro:wh|what pro:sub|I aux|have adv|now',
#   '*MOT:wait .'],
#  ['%mor:co|wait .', '*MOT:let me see .'],
#  ['%mor:v|let&ZERO pro:obj|me v|see .', '*CHI:I want to hold it .'],
#  ['%mor:pro:sub|I v|want inf|to v|hold pro|it .',
#   "*MOT:alright, you're gonna hold it ?"],
#  ['%mor:co|alright cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|hold pro|it ?',
#   "*MOT:that's it ."],
#  ['%mor:pro:dem|that~v:cop|be&3S pro|it .', '*MOT:just hold it .'],
#  ['%mor:adv:int|just v|hold pro|it .', '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*MOT:look what I have now .'],
#  ['%mor:v|look pro:wh|what pro:sub|I aux|have adv|now .',
#   '*MOT:look at the toys that I have .'],
#  ['%mor:v|look prep|at det|the n|toy-PL rel|that pro:sub|I v|have .',
#   '*CHI:can I see ?'],
#  ['%mor:aux|can pro:sub|I v|see ?', '*CHI:a magic wand .'],
#  ['%mor:det|a adj|magic n|wand .', '*MOT:a magic wand .'],
#  ['%mor:det|a adj|magic n|wand .', '*MOT:oh .'],
#  ['%mor:co|oh .', '*CHI:snake .'],
#  ['%mor:n|snake .', '*MOT:a snake .'],
#  ['%mor:det|a n|snake .', '*MOT:oh .'],
#  ['%mor:co|oh .', '*MOT:what is that ?'],
#  ['%mor:pro:wh|what v:cop|be&3S pro:dem|that ?', '*CHI:an elephant .'],
#  ['%mor:det|a n|elephant .', '*MOT:elephant .'],
#  ['%mor:n|elephant .', '*MOT:oh .'],
#  ['%mor:co|oh .', '*CHI:glasses .'],
#  ['%mor:n|glass-PL .', '*CHI:a car .'],
#  ['%mor:det|a n|car .', '*MOT:cool car .'],
#  ['%mor:adj|cool n|car .', '*MOT:the doors open .'],
#  ['%mor:det|the n|door-PL adv|open .', '*MOT:those are pretty neat huh ?'],
#  ['%mor:pro:dem|those v:cop|be&PRES adv:int|pretty adj|neat co|huh ?',
#   '*INV1:xxx .'],
#  ["*MOT:there's two more toys .",
#   '%mor:adv:loc|there~v:cop|be&3S det:num|two adv|more v|toy-3S .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*CHI:these are elephants .',
#   '%mor:pro:dem|these v:cop|be&PRES n|elephant-PL .'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ['*CHI:this is the baby elephant .',
#   '%mor:pro:dem|this v:cop|be&3S det|the adj|babe&dn-Y n|elephant .'],
#  ["*CHI:that's the .", '%mor:pro:dem|that~v:cop|be&3S det|the .'],
#  ['*MOT:which elephant is this ?',
#   '%mor:rel|which n|elephant v:cop|be&3S det|this ?'],
#  ['*CHI:a bigger one .', '%mor:det|a adj|big-CP pro:indef|one .'],
#  ['*CHI:this is the baby one .',
#   '%mor:pro:dem|this v:cop|be&3S det|the n|baby pro:indef|one .'],
#  ["*CHI:that's his sister one .",
#   '%mor:pro:dem|that~v:cop|be&3S pro:poss:det|his n|sister pro:indef|one .'],
#  ['*MOT:oh very nice .', '%mor:co|oh adv:int|very adj|nice .'],
#  ['*MOT:where are they gonna go ?',
#   '%mor:adv:wh|where v:cop|be&PRES pro:sub|they v|go-PROG~inf|to v|go ?'],
#  ['*CHI:to the school bus .', '%mor:prep|to det|the n|school n|bus .'],
#  ['*CHI:a elephant school bus .', '%mor:det|a n|elephant n|school n|bus .'],
#  ['*MOT:the elephant school bus .',
#   '%mor:det|the n|elephant n|school n|bus .'],
#  ['*MOT:oh, stop .', '%mor:co|oh cm|cm n|stop .'],
#  ['*MOT:time to let the elephants on .',
#   '%mor:n|time inf|to v|let&ZERO det|the n|elephant-PL adv|on .'],
#  ['*MOT:open the door .', '%mor:v|open det|the n|door .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:which elephant goes first ?',
#   '%mor:rel|which n|elephant v|go-3S adv|first ?'],
#  ['*CHI:baby one .', '%mor:adj|babe&dn-Y pro:indef|one .'],
#  ['*MOT:and what do elephants say ?',
#   '%mor:coord|and pro:wh|what v|do n|elephant-PL v|say ?'],
#  ["*MOT:wow, that's pretty cool .",
#   '%mor:co|wow cm|cm pro:dem|that~v:cop|be&3S adv:int|pretty adj|cool .'],
#  ['*MOT:how do they say it ?',
#   '%mor:adv:wh|how v|do pro:sub|they v|say pro|it ?'],
#  ['*MOT:how do they say that ?',
#   '%mor:adv:wh|how v|do pro:sub|they v|say rel|that ?'],
#  ['*CHI:with their trunks .',
#   '%mor:prep|with pro:poss:det|their n|trunk-PL .'],
#  ['*MOT:with their trunks .',
#   '%mor:prep|with pro:poss:det|their n|trunk-PL .'],
#  ['*CHI:they put the suitcase at the back .',
#   '%mor:pro:sub|they v|put&ZERO det|the n|suitcase prep|at det|the n|back .'],
#  ['*MOT:put the suitcase in the back .',
#   '%mor:v|put&ZERO det|the n|suitcase prep|in det|the n|back .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ["*MOT:that's very smart .",
#   '%mor:pro:dem|that~v:cop|be&3S adv:int|very adj|smart .'],
#  ['*MOT:which elephant goes next ?',
#   '%mor:rel|which n|elephant v|go-3S adv|next ?'],
#  ['*CHI:this one .', '%mor:det|this pro:indef|one .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:and then last but not least .',
#   '%mor:coord|and adv:tem|then n|last conj|but neg|not adj|least .'],
#  ['*MOT:oh, mommy might need to go in the top .',
#   '%mor:co|oh cm|cm n|mommy aux|might v|need inf|to v|go prep|in det|the n|top'],
#  ['*MOT:there we go .', '%mor:adv:loc|there pro:sub|we v|go .'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*CHI:where the school ?', '%mor:adv:wh|where det|the n|school ?'],
#  ['*MOT:xxx .', '*CHI:there goes xxx .'],
#  ['%mor:adv:loc|there v|go-3S .', '*MOT:xxx wants to .'],
#  ['%mor:v|want-3S prep|to .',
#   '*MOT:alright, you wanna play with the remote control car again ?'],
#  ['%mor:co|alright cm|cm pro|you v|want~inf|to v|play prep|with det|the adj|remote',
#   '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*MOT:yeah .'],
#  ['%mor:co|yeah .', '*MOT:alright .'],
#  ['%mor:co|alright .', '*CHI:and the balloon pumper .'],
#  ['%mor:coord|and det|the n|balloon n|pump&dv-AGT .',
#   '*MOT:and the balloon pumper .'],
#  ['%mor:coord|and det|the n|balloon n|pump&dv-AGT .', '*CHI:yeah, you can .'],
#  ['%mor:co|yeah cm|cm pro|you aux|can .',
#   '*CHI:I can do car, you can do the balloon pumper .'],
#  ['%mor:pro:sub|I aux|can v|do n|car cm|cm pro|you aux|can v|do det|the n|balloon',
#   '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:that sounds great to me .'],
#  ['%mor:det|that adj|sound-PL adj|great prep|to pro:obj|me .', '*MOT:okay .'],
#  ['%mor:co|okay .', '*MOT:so where are you gonna go with the car ?'],
#  ['%mor:co|so rel|where aux|be&PRES pro|you v|go-PROG~inf|to v|go prep|with det|the',
#   '*MOT:woah, get the bus out of the way ?'],
#  ['%mor:int|woah cm|cm v|get det|the n|bus prep|out prep|of det|the n|way ?',
#   '*MOT:oh .'],
#  ['%mor:co|oh .', '*MOT:oh my goodness .'],
#  ['%mor:co|oh co|my int|goodness .', '*CHI:make it big .'],
#  ['%mor:v|make pro|it adj|big .',
#   '*MOT:are we done playing with the car already ?'],
#  ['%mor:v:cop|be&PRES pro:sub|we adj|done adj:part|play-PROG prep|with det|the',
#   '*CHI:no .'],
#  ['%mor:co|no .',
#   "*MOT:well why don't you do the car and I'll do the balloon ."],
#  ['%mor:co|well adv:wh|why aux|do~neg|not pro|you v|do det|the n|car coord|and',
#   '*MOT:okay ?'],
#  ['%mor:co|okay ?', '*CHI:okay .'],
#  ['%mor:co|okay .', '*MOT:alright, where is it gonna go next ?'],
#  ['%mor:co|alright cm|cm rel|where aux|be&3S pro|it v|go-PROG~inf|to v|go adv|next',
#   '*MOT:woah, woah, woah .'],
#  ['%mor:int|woah cm|cm int|woah cm|cm int|woah .',
#   "*CHI:it's gonna go there ."],
#  ['%mor:pro|it~aux|be&3S v|go-PROG~inf|to v|go adv:loc|there .',
#   '*MOT:there we go .'],
#  ['%mor:adv:loc|there pro:sub|we v|go .', '*MOT:xxx forward silly .'],
#  ['%mor:adj|forward adj|silly .', '*MOT:ah, crash .'],
#  ['%mor:co|ah cm|cm n|crash .', '*MOT:crashed into everybody .'],
#  ['%mor:v|crash-PAST prep|into pro:indef|everybody .',
#   '*MOT:run over those poor kids .'],
#  ['%mor:v|run prep|over det|those adj|poor n|kid-PL .',
#   '*MOT:oh my goodness .'],
#  ['%mor:co|oh co|my int|goodness .', '*MOT:ah .'],
#  ['%mor:co|ah .', '*MOT:you ran the mommy .'],
# ...
#  ['%mor:co|okay cm|cm pro:sub|he~v:cop|be&3S adj|little .',
#   '*MOT:yes, he is little .'],
#  ['%mor:co|yes cm|cm pro:sub|he v:cop|be&3S adj|little .',
#   '*MOT:what else do you dry on the baby ?'],
#  ['%mor:pro:wh|what post|else v|do pro|you v|dry prep|on det|the n|baby ?',
#   '*CHI:everything .'],
#  ['%mor:pro:indef|everything .', '*MOT:everything ?'],
#  ['%mor:pro:indef|everything ?', '*MOT:like what ?'],
#  ['%mor:prep|like pro:wh|what ?', '*CHI:now we need to give him a pillow .'],
#  ['%mor:adv|now pro:sub|we v|need inf|to v|give pro:obj|him det|a n|pillow .',
#   "*MOT:and then what do you do with the baby's hair when you're done"],
#  ['%mor:coord|and adv:tem|then pro:wh|what aux|do pro|you v|do prep|with det|the',
#   '*CHI:uhm, you just brush his baby hair .'],
#  ['%mor:?|uhm cm|cm pro|you adv:int|just v|brush pro:poss:det|his n|baby n|hair',
#   '*MOT:very nice .'],
#  ['%mor:adv:int|very adj|nice .', '*MOT:are you gonna feed the baby ?'],
#  ['%mor:aux|be&PRES pro|you v|go-PROG~inf|to v|feed det|the n|baby ?',
#   '*MOT:Lester, are you gonna feed the baby ?'],
#  ['%mor:n:prop|Lester cm|cm aux|be&PRES pro|you v|go-PROG~inf|to v|feed det|the',
#   '*CHI:okay .'],
#  ['%mor:co|okay .', '*MOT:what do you feed him ?'],
#  ['%mor:pro:wh|what aux|do pro|you v|feed pro:obj|him ?',
#   '*MOT:you should probably feed the baby from the containers .'],
#  ['%mor:pro|you aux|should adv|probable&dadj-LY v|feed det|the n|baby prep|from',
#   '*MOT:from the baby food containers .'],
#  ['%mor:prep|from det|the n|baby n|food n|contain&dv-AGT-PL .',
#   "*MOT:oh, you're a good opener ."],
#  ['%mor:co|oh cm|cm pro|you~v:cop|be&PRES det|a adj|good n|open&dv-AGT .',
#   '*MOT:oh, baby eats skittles .'],
#  ['%mor:co|oh cm|cm n|baby v|eat-3S n|skittle-PL .',
#   "*MOT:I don't think so ."],
#  ['%mor:pro:sub|I aux|do~neg|not v|think co|so .',
#   "*MOT:baby's don't have teeth ."],
#  ['%mor:n|baby~poss|s aux|do~neg|not v|have n|tooth&PL .',
#   "*MOT:you didn't feed the baby ."],
#  ['%mor:pro|you aux|do&PAST~neg|not v|feed det|the n|baby .',
#   '*MOT:gotta use the spoon .'],
#  ['%mor:v|get&PAST~inf|to v|use det|the n|spoon .', '*MOT:to feed the baby .'],
#  ['%mor:inf|to v|feed det|the n|baby .', '*CHI:I just did .'],
#  ['%mor:pro:sub|I adv:int|just v|do&PAST .',
#   '*MOT:what kind of food did you feed the baby ?'],
#  ['%mor:pro:wh|what n|kind prep|of n|food v|do&PAST pro|you v|feed det|the n|baby',
#   '*CHI:some shampoo .'],
#  ['%mor:qn|some n|shampoo .', '*MOT:some shampoo ?'],
#  ['%mor:qn|some n|shampoo ?', '*MOT:oh .'],
#  ['%mor:co|oh .', '%mor:unk|xxx . '],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ["*MOT:babies don't eat shampoo .",
#   '%mor:n|baby-PL aux|do~neg|not v|eat n|shampoo .'],
#  ['*MOT:what do babies eat ?', '%mor:det:wh|what v|do n|baby-PL v|eat ?'],
#  ["*MOT:that's so silly .",
#   '%mor:pro:dem|that~v:cop|be&3S adv:int|so adj|silly .'],
#  ['%mor:unk|xxx . ', '*MOT:what are you doing with the car ?'],
#  ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG prep|with det|the n|car ?',
#   '*CHI:back it up .'],
#  ['%mor:adv:loc|back pro|it adv:loc|up .', '*MOT:backing it up ?'],
#  ['%mor:adj:part|back-PROG pro|it adv:loc|up ?', '*MOT:now what ?'],
#  ['%mor:adv|now pro:wh|what ?',
#   "*MOT:ah, you're gonna run the poor baby over ."],
#  ['%mor:co|ah cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|run det|the adj|poor',
#   '*CHI:xxx .'],
#  ['*MOT:what letter is this ?',
#   '%mor:pro:wh|what n|letter v:cop|be&3S det|this ?'],
#  ['*CHI:k@l .', '%mor:n:let|k .'],
#  ['*MOT:what number is this ?',
#   '%mor:pro:wh|what n|number v:cop|be&3S det|this ?'],
#  ['*CHI:uhm, five .', '%mor:?|uhm cm|cm det:num|five .'],
#  ['*CHI:xxx .', '*MOT:alright, what letters are these ?'],
#  ['%mor:co|alright cm|cm pro:wh|what n|letter-PL v:cop|be&PRES det|these ?',
#   '*MOT:Lester, what letter is this ?'],
#  ['%mor:n:prop|Lester cm|cm pro:wh|what n|letter v:cop|be&3S det|this ?',
#   '*CHI:e@l, b@l, j@l, y@l .'],
#  ['%mor:n:let|e cm|cm n:let|b cm|cm n:let|j cm|cm n:let|y .',
#   '*MOT:and this ?'],
#  ['%mor:coord|and pro:dem|this ?', '*CHI:a@l .'],
#  ['%mor:n:let|a .', "*MOT:what's this ?"],
#  ['%mor:pro:wh|what~v:cop|be&3S pro:dem|this ?', '*CHI:uhm, xxx .'],
#  ['%mor:?|uhm cm|cm .', '*CHI:f@l .'],
#  ['%mor:n:let|f .', '*CHI:I cannot do everything .'],
#  ['%mor:pro:sub|I aux|can~neg|not v|do pro:indef|everything .',
#   "*MOT:what's this one ?"],
#  ['%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?',
#   '*CHI:I want this xxx .'],
#  ['%mor:pro:sub|I v|want det|this .', '*CHI:like this .'],
#  ['%mor:prep|like pro:dem|this .', '*MOT:you want the what part ?'],
#  ['%mor:pro|you v|want det|the pro:wh|what n|part ?', '*CHI:this .'],
#  ['%mor:det|this .', '*MOT:what is that ?'],
#  ['%mor:pro:wh|what v:cop|be&3S pro:dem|that ?',
#   "*CHI:it's a balloon pumper ."],
#  ['%mor:pro|it~v:cop|be&3S det|a n|balloon n|pump&dv-AGT .',
#   "*MOT:it's a balloon pumper ."],
#  ['%mor:pro|it~v:cop|be&3S det|a n|balloon n|pump&dv-AGT .', '*CHI:yeah .'],
#  ['%mor:co|yeah .', '*MOT:can you say balloon pumper .'],
#  ['%mor:aux|can pro|you co|say n|balloon n|pump&dv-AGT .',
#   '*CHI:balloon pumper .'],
#  ['%mor:n|balloon n|pump&dv-AGT .', '*MOT:look at my mouth please .'],
#  ['%mor:n|look prep|at pro:poss:det|my n|mouth v|please .', '*MOT:balloon .'],
#  ['%mor:n|balloon .', '*CHI:balloon .'],
#  ['%mor:n|balloon .', '*MOT:balloon .'],
#  ['%mor:n|balloon .', '*CHI:I just said that .'],
#  ['%mor:pro:sub|I adv:int|just v|say&PAST rel|that .', '*MOT:look at me .'],
#  ['%mor:n|look prep|at pro:obj|me .', '*CHI:balloon pumper .'],
#  ['%mor:n|balloon n|pump&dv-AGT .', '*MOT:very close .'],
#  ['%mor:adv:int|very adj|close .', '*MOT:look at me buddy .'],
#  ['%mor:n|look prep|at pro:obj|me n|buddy .', '*CHI:can you xxx .'],
#  ['%mor:aux|can pro|you .', '*MOT:what are you doing ?'],
#  ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?',
#   '*MOT:what are you doing ?'],
#  ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?',
#   "*CHI:uhm, I'm doing this ."],
#  ['%mor:?|uhm cm|cm pro:sub|I~aux|be&1S part|do-PROG det|this .',
#   "*CHI:I'm making a balloon ."],
#  ['%mor:pro:sub|I~aux|be&1S part|make-PROG det|a n|balloon .',
#   '*MOT:what color is the balloon ?'],
#  ['%mor:pro:wh|what n|color v:cop|be&3S det|the n|balloon ?', '*CHI:red .'],
#  ['%mor:adj|red .', '*MOT:okay, stop pumping .'],
#  ['%mor:co|okay cm|cm n|stop adj:part|pump-PROG .', '*CHI:okay, now .'],
#  ['%mor:unk|xxx . ', '%mor:co|okay cm|cm adv|now .'],
#  ['*MOT:okay, stop pumping .',
#   '%mor:co|okay cm|cm n|stop adj:part|pump-PROG .'],
#  ["*MOT:what's gonna happen when the balloon is all filled up ?",
#   '%mor:pro:wh|what~aux|be&3S v|go-PROG~inf|to v|happen conj|when det|the n|balloon'],
#  ["*CHI:it's going to explode .",
#   '%mor:pro|it~aux|be&3S part|go-PROG inf|to v|explode .'],
#  ['*MOT:explode .', '%mor:v|explode .'],
#  ["*MOT:okay, that's enough .",
#   '%mor:co|okay cm|cm rel|that~aux|be&3S adv|enough .'],
#  ["*MOT:alright, that's big enough .",
#   '%mor:co|alright cm|cm pro:dem|that~v:cop|be&3S adj|big adv|enough .'],
#  ['*MOT:what are you gonna do with it now ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with pro|it'],
#  ["*MOT:snake's eating your toe .",
#   '%mor:n|snake~aux|be&3S part|eat-PROG pro:poss:det|your n|toe .'],
#  ['*CHI:ah .', '%mor:co|ah .'],
#  ['*CHI:xxx .', "*MOT:here, let's play with this one ."],
#  ['%mor:adv:loc|here cm|cm v|let~pro|us v|play prep|with det|this pro:indef|one',
#   "*MOT:we haven't playing with this one at all ."],
#  ['%mor:pro:sub|we aux|have~neg|not part|play-PROG prep|with det|this pro:indef|one',
#   '*MOT:xxx .'],
#  ['%mor:unk|xxx . ', "*MOT:let's see ."],
#  ['%mor:v|let~pro|us co|see .', '*MOT:what is this ?'],
#  ['%mor:pro:wh|what v:cop|be&3S det|this ?', '*CHI:a clown .'],
#  ['%mor:det|a n|clown .', '*MOT:are they all clowns ?'],
#  ['%mor:v:cop|be&PRES pro:sub|they adv:int|all n|clown-PL ?',
#   "*MOT:what's that one ?"],
#  ['%mor:pro:wh|what~aux|be&3S det|that pro:indef|one ?', '*CHI:ah xxx .'],
#  ['%mor:co|ah .', '*MOT:and that one ?'],
#  ['%mor:coord|and rel|that pro:indef|one ?', '*CHI:a tiger .'],
#  ['%mor:det|a n|tiger .', '*CHI:and a clown .'],
#  ['%mor:coord|and det|a n|clown .', '*CHI:and a xxx .'],
#  ['%mor:coord|and det|a .', "*MOT:you're a what ?"],
#  ['%mor:pro|you~v:cop|be&PRES det|a pro:wh|what ?', '*CHI:xxx .'],
#  ['*MOT:a jumpy ?', '%mor:det|a adj|jump&dn-Y ?'],
#  ['*MOT:should we put sunglasses on the baby ?',
#   '%mor:aux|should pro:sub|we v|put&ZERO n|sunglass-PL prep|on det|the n|baby'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*MOT:you wanna wear some sunglasses ?',
#   '%mor:pro|you v|want~inf|to v|wear qn|some n|sunglass-PL ?'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*CHI:baby wants to .', '%mor:n|baby v|want-3S prep|to .'],
#  ['*MOT:the baby wants to .', '%mor:det|the n|baby v|want-3S prep|to .'],
#  ['*CHI:can you tie this ?', '%mor:aux|can pro|you v|tie det|this ?'],
#  ["*INV1:we'll do it once we're done, okay ?",
#   '%mor:pro:sub|we~mod|will aux|do pro|it adv|once pro:sub|we~v:cop|be&PRES adj|done'],
#  ['*MOT:come here buddy .', '%mor:v|come adv:loc|here n|buddy .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ['*CHI:okay .', '%mor:co|okay .'],
#  ["*MOT:okay, we'll play with this as soon as we're done .",
#   '%mor:co|okay cm|cm pro:sub|we~mod|will v|play prep|with det|this adv|as adv|soon'],
#  ['*MOT:how many animals are there ?',
#   '%mor:adv:wh|how qn|many n|animal-PL v:cop|be&PRES adv:loc|there ?'],
#  ['*CHI:one, two, three .',
#   '%mor:det:num|one cm|cm det:num|two cm|cm det:num|three .'],
#  ["*CHI:there's three .", '%mor:adv:loc|there~v:cop|be&3S det:num|three .'],
#  ['*MOT:what about those animals ?',
#   '%mor:pro:wh|what adv|about det|those n|animal-PL ?'],
#  ['*MOT:over there .', '%mor:prep|over adv:loc|there .'],
#  ['*MOT:and these animals .', '%mor:coord|and det|these n|animal-PL .'],
#  ['*MOT:count all the animals .', '%mor:v|count qn|all det|the n|animal-PL .'],
#  ['*CHI:can I have .', '%mor:aux|can pro:sub|I v|have .'],
#  ['*CHI:hey .', '%mor:co|hey .'],
#  ['*CHI:I want the balloon back .',
#   '%mor:pro:sub|I v|want det|the n|balloon adv:loc|back .'],
#  ['*CHI:can I ?', '%mor:aux|can pro:sub|I ?'],
#  ['*MOT:what do you say ?', '%mor:pro:wh|what aux|do pro|you v|say ?'],
#  ['*CHI:please .', '%mor:co|please .'],
#  ['*MOT:please what ?', '%mor:v|please pro:wh|what ?'],
#  ['*CHI:please I can have the balloon back ?',
#   '%mor:v|please pro:sub|I aux|can v|have det|the n|balloon adv:loc|back ?'],
#  ['*MOT:please can I have the balloon .',
#   '%mor:v|please aux|can pro:sub|I v|have det|the n|balloon .'],
#  ['*CHI:please I can have balloon ?',
#   '%mor:v|please pro:sub|I aux|can v|have n|balloon ?'],
#  ['*MOT:Lester, please can I have the balloon .',
#   '%mor:n:prop|Lester cm|cm v|please aux|can pro:sub|I v|have det|the n|balloon'],
#  ['*CHI:please can I have a balloon ?',
#   '%mor:v|please aux|can pro:sub|I v|have det|a n|balloon ?'],
#  ['*MOT:very good .', '%mor:adv:int|very adj|good .'],
#  ['*MOT:you may .', '%mor:pro|you aux|may .'],
#  ['*CHI:can you put it on here ?',
#   '%mor:aux|can pro|you v|put&ZERO pro|it prep|on adv:loc|here ?'],
#  ['*CHI:can you ?', '%mor:aux|can pro|you ?'],
#  ["*MOT:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .'],
#  ['*MOT:can I ?', '%mor:aux|can pro:sub|I ?'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:oh yeah ?', '%mor:co|oh co|yeah ?'],
#  ['*MOT:how do I do it ?', '%mor:adv:wh|how v|do pro:sub|I v|do pro|it ?'],
#  ['*MOT:how do I do it ?', '%mor:adv:wh|how v|do pro:sub|I v|do pro|it ?'],
#  ['*CHI:you just do this and put it on .',
#   '%mor:pro|you adv:int|just v|do pro:dem|this coord|and v|put&ZERO pro|it adv|on'],
#  ['*MOT:oh really ?', '%mor:co|oh adv:int|really ?'],
#  ['*MOT:just like this ?', '%mor:adv:int|just prep|like pro:dem|this ?'],
#  ['*CHI:then you pump it .', '%mor:adv:tem|then pro|you v|pump pro|it .'],
#  ['*CHI:then you do that .', '%mor:adv:tem|then pro|you v|do pro:dem|that .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ["*MOT:you're very smart .",
#   '%mor:pro|you~v:cop|be&PRES adv:int|very adj|smart .'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*MOT:okay .', '%mor:co|okay .'],
#  ['*MOT:I did this .', '%mor:pro:sub|I v|do&PAST det|this .'],
#  ['*MOT:I put it on .', '%mor:pro:sub|I v|put&ZERO pro|it adv|on .'],
#  ['*CHI:then .', '%mor:adv:tem|then .'],
#  ['*MOT:then what ?', '%mor:adv:tem|then pro:wh|what ?'],
#  ['*MOT:alright .', '%mor:co|alright .'],
#  ["*MOT:you don't hold this while you're pumping it though .",
#   '%mor:pro|you aux|do~neg|not v|hold det|this n|while pro|you~aux|be&PRES part|pump-PROG'],
#  ['*MOT:okay, woah .', '%mor:co|okay cm|cm int|woah .'],
#  ['*MOT:what are you doing ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?'],
#  ['*MOT:what are you doing ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?'],
#  ["*CHI:I'm making a giant balloon .",
#   '%mor:pro:sub|I~aux|be&1S part|make-PROG det|a n|giant n|balloon .'],
#  ["*MOT:you're making a giant balloon .",
#   '%mor:pro|you~aux|be&PRES part|make-PROG det|a n|giant n|balloon .'],
#  ['*MOT:what color is the balloon ?',
#   '%mor:pro:wh|what n|color v:cop|be&3S det|the n|balloon ?'],
#  ['*CHI:red .', '%mor:unk|xxx . '],
#  ['%mor:adj|red .', '*MOT:red .'],
#  ['%mor:adj|red .', '*MOT:what color if you had another color balloon .'],
#  ['%mor:pro:wh|what n|color conj|if pro|you v|have&PAST qn|another n|color n|balloon',
#   '*MOT:what color would you want ?'],
#  ['%mor:pro:wh|what n|color aux|will&COND pro|you v|want ?', '*CHI:pink .'],
#  ['%mor:adj|pink .', '*MOT:pink .'],
#  ['%mor:adj|pink .', "*MOT:and if you couldn't get a pink balloon ."],
#  ['%mor:coord|and conj|if pro|you aux|could~neg|not v|get det|a adj|pink n|balloon',
#   '*MOT:what color would you want then ?'],
#  ['%mor:pro:wh|what n|color aux|will&COND pro|you v|want adv:tem|then ?',
#   '*CHI:a orange .'],
#  ['%mor:det|a n|orange .', '*MOT:orange .'],
#  ['%mor:adj|orange .', "*MOT:if you couldn't have an orange balloon ?"],
#  ['%mor:conj|if pro|you aux|could~neg|not v|have det|a n|orange n|balloon ?',
#   '*CHI:xxx .'],
#  ['*MOT:what color is in the rainbow ?',
#   '%mor:pro:wh|what n|color v:cop|be&3S prep|in det|the n|+n|rain+n|bow ?'],
#  ["*CHI:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .'],
#  ['*MOT:what ?', '%mor:pro:wh|what ?'],
#  ["*MOT:you don't know ?", '%mor:pro|you aux|do~neg|not v|know ?'],
#  ["*MOT:I'm going to take my magic wand and turn you into a frog .",
#   '%mor:pro:sub|I~aux|be&1S part|go-PROG inf|to v|take pro:poss:det|my n|magic'],
#  ['*MOT:oh, did you hear that ?',
#   '%mor:co|oh cm|cm v|do&PAST pro|you v|hear pro:dem|that ?'],
#  ['*CHI:yeah .', '%mor:co|yeah .'],
#  ['*CHI:is this xxx .', '%mor:v:cop|be&3S det|this .'],
#  ["*MOT:what's the frog saying ?",
#   '%mor:pro:wh|what~aux|be&3S det|the n|frog adj:part|say-PROG ?'],
#  ["*MOT:I'm going to turn you into a frog with my magic wand .",
#   '%mor:pro:sub|I~aux|be&1S part|go-PROG inf|to v|turn pro|you prep|into det|a'],
#  ['*MOT:alakazam .', '%mor:?|alakazam .'],
#  ['*MOT:Lester is a froggie .',
#   '%mor:n:prop|Lester v:cop|be&3S det|a n|frog-DIM .'],
#  ['*MOT:did it work ?', '%mor:v|do&PAST pro|it v|work ?'],
#  ['*MOT:are you a frog ?', '%mor:aux|be&PRES pro|you det|a n|frog ?'],
#  ['*CHI:no .', '%mor:co|no .'],
#  ['*CHI:abracadabra .', '%mor:?|abracadabra .'],
#  ['*MOT:oh .', '%mor:co|oh .'],
#  ['*CHI:I just turned you into xxx .',
#   '%mor:pro:sub|I adv:int|just v|turn-PAST pro|you prep|into .'],
#  ["*MOT:I'm a vegetable ?", '%mor:pro:sub|I~v:cop|be&1S det|a n|vegetable ?'],
#  ['*CHI:no, invisible .', '%mor:co|no cm|cm in#adj|visible .'],
#  ['*MOT:oh invisible .', '%mor:co|oh in#adj|visible .'],
#  ['*CHI:where you can xxx walls .',
#   '%mor:adv:wh|where pro|you aux|can n|wall-PL .'],
#  ["*MOT:that's not very nice .",
#   '%mor:pro:dem|that~v:cop|be&3S neg|not adv:int|very adj|nice .'],
#  ['*MOT:woah, that balloon is huge Lester .',
#   '%mor:int|woah cm|cm rel|that v|balloon v:cop|be&3S adj|huge n:prop|Lester .'],
#  ['*MOT:what are you gonna do with that balloon ?',
#   '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with det|that'],
#  ['*CHI:explode it .', '%mor:v|explode pro|it .'],
#  ["*MOT:you're gonna explode it ?",
#   '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v|explode pro|it ?']]

# %%
p = '.!?'

turn = []
speaker = []
mor = []
for i, val in enumerate(grouped):
    turn.append(i+1)

for i in grouped:
    print(i)
    s = i[0]
    m = i[1]
    for c in p:
        m = m.replace(c, '')
        m = m.strip()
        m = m.replace('%mor:', '')
    speaker.append(s[1:4])
    mor.append(m)

z = list(zip(turn, speaker, mor))


turn = []
speaker = []
pss = []
wds = []
for i, val in enumerate(z):
    x = z[i]
    t = x[0]
    s = x[1]
    m = x[2]
    m = m.split(' ')
    p = []
    w = []
    for n in m:
        temp = n.split('|')
        p.append(temp[0])
        w.append(temp[1])
    turn.append(t)
    speaker.append(s)
    pss.append(p)
    wds.append(w) 

pw = list(zip(turn,speaker,pss,wds))


lines = []
for i in pw:
    num = str(i[0])
    speaker = i[1]
    wds = i[3]
    pss = i[2]
    for j, val in enumerate(pss):
        p = pss[j]
        w = wds[j]
        temp = num + ',' + speaker + ',' + w + ',' + p + '\n'
        lines.append(temp)  


lines2 = []
sep = '-~&'
for i in lines:
    s = i.split(',')
    w1 = s[2]
    for c in sep:
        w1 = w1.replace(c, '$')
    w1 = w1.split('$')
    w1 = w1[0]
    num = s[0]
    speaker = s[1]
    word = w1
    wordplus = s[2]
    pos = s[3]
    temp = num + ',' + speaker + ',' + word + ',' + wordplus + ',' + pos
    lines2.append(temp)




header = 'Turn,' + 'Speaker,' + 'Word,' + 'WordPlus,' + 'POS' + '\n'
data = ''.join(lines2)
output = header + data
# Out:
# ['*MOT:do you want to feed them first ?', '%mor:aux|do pro|you v|want inf|to v|feed pro:obj|them adv|first ?']
# ['*MOT:then go to sleep .', '%mor:adv:tem|then v|go inf|to v|sleep .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:okay .', '%mor:co|okay .']
# ["*MOT:here's the baby bottle .", '%mor:adv:loc|here~v:cop|be&3S det|the n|baby n|bottle .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:now give .', '%mor:adv|now v|give .']
# ['*MOT:you gotta burp the baby .', '%mor:pro|you v|get&PAST~inf|to v|burp det|the n|baby .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:oh my goodness that baby burps so crazy .', '%mor:co|oh pro:poss:det|my n|good&dadj-NESS det|that n|baby v|burp-3S']
# ['*MOT:now is the pillow all set ?', '%mor:adv|now v:cop|be&3S det|the n|pillow adv:int|all adj|set ?']
# ['*MOT:is the blanket all nice ?', '%mor:v:cop|be&3S det|the n|blanket adv:int|all adj|nice ?']
# ['*CHI:xxx .', '%mor:unk|xxx . ']
# ['*MOT:mhm .', '%mor:co|yes .']
# ["*MOT:and what's that ?", '%mor:coord|and pro:wh|what~v:cop|be&3S pro:dem|that ?']
# ['*MOT:is that a pillow ?', '%mor:v:cop|be&3S pro:dem|that det|a n|pillow ?']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*CHI:see .', '%mor:v|see .']
# ['*CHI:xxx need to be over here .', '%mor:v|need inf|to v:cop|be prep|over adv:loc|here .']
# ['*CHI:the baby need to be right here .', '%mor:det|the n|baby v|need inf|to v:cop|be adv|right adv:loc|here .']
# ['*CHI:and a blanket .', '%mor:coord|and det|a n|blanket .']
# ['*MOT:okay, very good .', '%mor:co|okay cm|cm adv:int|very adj|good .']
# ['%mor:unk|xxx . ', '*CHI:xxx .']
# ["*MOT:you're gonna be a very good daddy someday .", '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v:cop|be det|a adv:int|very adj|good']
# ['*MOT:huh ?', '%mor:co|huh ?']
# ['*MOT:very nice .', '%mor:adv:int|very adj|nice .']
# ['*CHI:I think the baby is hungry .', '%mor:pro:sub|I v|think det|the n|baby v:cop|be&3S adj|hungry .']
# ['*MOT:the baby just ate .', '%mor:det|the n|baby adv:int|just v|eat&PAST .']
# ['*MOT:and you just burped the baby .', '%mor:coord|and pro|you adv:int|just v|burp-PAST det|the n|baby .']
# ['*MOT:the baby is hungry again ?', '%mor:unk|xxx . ']
# ['%mor:det|the n|baby v:cop|be&3S adj|hungry adv|again ?', '*CHI:xxx .']
# ['*MOT:gulp gulp gulp .', '%mor:n|gulp n|gulp n|gulp .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*MOT:baby burped .', '%mor:n|baby v|burp-PAST .']
# ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .']
# ['*MOT:can you .', '%mor:aux|can pro|you .']
# ['*MOT:can you stack these blocks up ?', '%mor:aux|can pro|you v|stack det|these n|block-PL prep|up ?']
# ['*MOT:with the biggest one on the bottom .', '%mor:prep|with det|the adj|big-SP pro:indef|one prep|on det|the n|bottom .']
# ['*MOT:and the smallest one on the top .', '%mor:coord|and det|the adj|small-SP pro:indef|one prep|on det|the n|top .']
# ['*CHI:oh .', '%mor:co|oh .']
# ['*MOT:biggest one on the bottom .', '%mor:adj|big-SP pro:indef|one prep|on det|the n|bottom .']
# ['*MOT:oh, turn it upside down .', '%mor:co|oh cm|cm v|turn pro|it adv|upside adv:loc|down .']
# ['*MOT:so we can stack them up .', '%mor:conj|so pro:sub|we aux|can v|stack pro:obj|them adv:loc|up .']
# ['*MOT:there you go .', '%mor:adv:loc|there pro|you v|go .']
# ['*MOT:big .', '%mor:adj|big .']
# ['*MOT:smaller .', '%mor:adj|small-CP .']
# ['*MOT:smaller .', '%mor:adj|small-CP .']
# ['*MOT:and smallest .', '%mor:coord|and adj|small-SP .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:you did a great job .', '%mor:pro|you v|do&PAST det|a adj|great n|job .']
# ['*MOT:what else can you put on top ?', '%mor:pro:wh|what post|else aux|can pro|you v|put&ZERO prep|on n|top ?']
# ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .']
# ['*MOT:blocks .', '%mor:n|block-PL .']
# ['*MOT:blocks .', '%mor:n|block-PL .']
# ['*MOT:another block ?', '%mor:qn|another n|block ?']
# ['*MOT:how many ?', '%mor:adv:wh|how qn|many ?']
# ['*MOT:three .', '%mor:det:num|three .']
# ['*MOT:four .', '%mor:det:num|four .']
# ['*MOT:five .', '%mor:det:num|five .']
# ['*MOT:six .', '%mor:det:num|six .']
# ['*MOT:woah .', '%mor:int|woah .']
# ['*MOT:seven .', '%mor:det:num|seven .']
# ['*MOT:eight .', '%mor:det:num|eight .']
# ["*MOT:there's one right in front of you too .", '%mor:adv:loc|there~v:cop|be&3S pro:indef|one adv|right prep|in n|front prep|of']
# ['*MOT:nine .', '%mor:det:num|nine .']
# ['*CHI:but this xxx .', '%mor:conj|but det|this .']
# ['*MOT:woah .', '%mor:int|woah .']
# ['*MOT:ahh .', '%mor:co|ahh .']
# ['*MOT:timber !', '%mor:n|timber !']
# ['*MOT:alright .', '%mor:co|alright .']
# ['*MOT:are you gonna make the car run over the teddy_bear ?', '%mor:aux|be&PRES pro|you v|go-PROG~inf|to v|make det|the n|car v|run prep|over']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*MOT:woah .', '%mor:int|woah .']
# ['*MOT:poor teddy_bear .', '%mor:adj|poor n|teddy_bear .']
# ['*MOT:teddy_bear can sit on top .', '%mor:n|teddy_bear aux|can v|sit prep|on n|top .']
# ['*MOT:holy cow !', '%mor:adj|holy n|cow !']
# ['*MOT:oh wow .', '%mor:co|oh co|wow .']
# ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .']
# ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .']
# ['*MOT:back it up .', '%mor:v|back pro|it adv:loc|up .']
# ['*MOT:gonna hit the octopus .', '%mor:v|go-PROG~inf|to v|hit&ZERO det|the n|octopus .']
# ['*MOT:oh no .', '%mor:co|oh co|no .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*MOT:the poor octopus .', '%mor:det|the adj|poor n|octopus .']
# ["*MOT:here, let's make .", '%mor:adv:loc|here cm|cm v|let~pro|us v|make .']
# ['*MOT:I know what we can do .', '%mor:pro:sub|I v|know pro:wh|what pro:sub|we aux|can v|do .']
# ['*MOT:wait, ready ?', '%mor:co|wait cm|cm adj|ready ?']
# ['*MOT:you gonna make the .', '%mor:pro|you v|go-PROG~inf|to v|make det|the .']
# ["*INV1:you're so silly .", '%mor:pro|you~v:cop|be&PRES adv:int|so adj|silly .']
# ['*MOT:come here Lester .', '%mor:v|come adv:loc|here n:prop|Lester .']
# ['*MOT:make the car come this way .', '%mor:v|make det|the n|car v|come det|this n|way .']
# ['*CHI:okay .', '%mor:co|okay .']
# ['%mor:unk|xxx . ', '*MOT:make the car and teddy_bear come this way .']
# ['%mor:v|make det|the n|car coord|and n|teddy_bear v|come det|this n|way .', '*CHI:xxx .']
# ['*INV1:you gonna set her up ?', '%mor:pro|you v|go-PROG~inf|to v|set&ZERO pro:obj|her prep|up ?']
# ['*MOT:oh no .', '%mor:co|oh co|no .']
# ['*MOT:the teddy_bear fell off .', '%mor:det|the n|teddy_bear v|fall&PAST adv|off .']
# ['*MOT:okay, back up .', '%mor:co|okay cm|cm v|back prep|up .']
# ['*MOT:come over here buddy .', '%mor:v|come prep|over adv:loc|here n|buddy .']
# ['*MOT:alright .', '%mor:co|alright .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:wait, can I see that car ?', '%mor:co|wait cm|cm aux|can pro:sub|I v|see det|that n|car ?']
# ["*MOT:oh, you're gonna play with the bus now ?", '%mor:co|oh cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|play prep|with det|the']
# ['*CHI:no, I need to make the driver stand up .', '%mor:co|no cm|cm pro:sub|I v|need inf|to v|make det|the n|drive&dv-AGT v|stand']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*CHI:now you can be that .', '%mor:adv|now pro|you aux|can v:cop|be pro:dem|that .']
# ["*MOT:okay, I'll be the car .", '%mor:co|okay cm|cm pro:sub|I~mod|will v:cop|be det|the n|car .']
# ['*MOT:alright, you be the bus .', '%mor:co|alright cm|cm pro|you v:cop|be det|the n|bus .']
# ['*CHI:no .', '%mor:co|no .']
# ['*CHI:I need .', '%mor:pro:sub|I v|need .']
# ['*CHI:I need .', '%mor:pro:sub|I v|need .']
# ['*CHI:I need to stack this up .', '%mor:pro:sub|I v|need inf|to v|stack pro:dem|this adv:loc|up .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:stack up all the blocks up .', '%mor:n|stack prep|up qn|all det|the n|block-PL prep|up .']
# ["*MOT:that's a good idea .", '%mor:pro:dem|that~v:cop|be&3S det|a adj|good n|idea .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:okay, good .', '%mor:co|okay cm|cm adj|good .']
# ['*CHI:make a xxx .', '%mor:v|make det|a .']
# ['*CHI:drive over this .', '%mor:v|drive prep|over det|this .']
# ['*MOT:okay .', '%mor:co|okay .']
# ["*CHI:then it's xxx .", '%mor:adv:tem|then pro|it~aux|be&3S .']
# ["*MOT:wow, you're gonna make that really tall .", '%mor:co|wow cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|make']
# ["*MOT:aren't you ?", '%mor:aux|be&PRES~neg|not pro|you ?']
# ['*MOT:how many are you using ?', '%mor:adv:wh|how qn|many aux|be&PRES pro|you v|use-PROG ?']
# ['*CHI:one two three four five six seven eight .', '%mor:det:num|one det:num|two det:num|three det:num|four det:num|five det:num|six']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*CHI:now .', '%mor:adv|now .']
# ['*CHI:where the control is .', '%mor:rel|where det|the n|control v:cop|be&3S .']
# ['*CHI:knock it down !', '%mor:v|knock pro|it adv:loc|down !']
# ['*CHI:ahh .', '%mor:co|ahh .']
# ['*CHI:make that school bus knock down .', '%mor:v|make det|that n|school n|bus n|knock adv:loc|down .']
# ['*MOT:oh, the octopus xxx on the .', '%mor:co|oh cm|cm det|the n|octopus prep|on det|the .']
# ['*MOT:your turn .', '%mor:pro:poss:det|your n|turn .']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*MOT:now what are you gonna do ?', '%mor:adv|now pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do ?']
# ['*CHI:build something .', '%mor:v|build pro:indef|something .']
# ['*MOT:what are you gonna build ?', '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|build ?']
# ['*CHI:a big tower .', '%mor:det|a adj|big n|tower .']
# ['*MOT:a big tower ?', '%mor:det|a adj|big n|tower ?']
# ["*MOT:oh that's really cool .", '%mor:co|oh pro:dem|that~v:cop|be&3S adv:int|really adj|cool .']
# ['*MOT:look at this .', '%mor:v|look prep|at pro:dem|this .']
# ["*MOT:this lady's got a wheelchair .", '%mor:det|this n|lady~aux|be&3S part|get&PERF det|a n|+n|wheel+n|chair .']
# ["*MOT:isn't that cool ?", '%mor:v:cop|be&3S~neg|not pro:dem|that adj|cool ?']
# ['*CHI:I could knock him down .', '%mor:pro:sub|I aux|could v|knock pro:obj|him adv:loc|down .']
# ['*MOT:no .', '%mor:co|no .']
# ['*MOT:we do not knock over people in wheelchairs .', '%mor:pro:sub|we aux|do neg|not v|knock prep|over n|person&PL prep|in n|+n|wheel+n|chair-PL']
# ["*MOT:that's .", '%mor:pro:dem|that~v:cop|be&3S .']
# ["*MOT:that's how they got that way sometimes .", '%mor:pro:dem|that~v:cop|be&3S adv:wh|how pro:sub|they v|get&PAST det|that n|way']
# ["*MOT:definitely don't need to do that huh .", '%mor:adv|definite&dadj-LY aux|do~neg|not v|need inf|to v|do pro:dem|that']
# ['*CHI:okay .', '%mor:unk|xxx . ']
# ['%mor:co|okay .', "*MOT:that's not nice ."]
# ['%mor:pro:dem|that~v:cop|be&3S neg|not adj|nice .', '*CHI:xxx .']
# ['%mor:unk|xxx . ', '*CHI:um .']
# ['%mor:co|um .', '*CHI:car .']
# ['%mor:n|car .', '*CHI:xxx .']
# ['*MOT:that was a car accident .', '%mor:pro:dem|that v:cop|be&PAST&13S det|a n|car n|accident .']
# ["*MOT:that's not good .", '%mor:pro:dem|that~v:cop|be&3S neg|not adj|good .']
# ['*CHI:where the policeman ?', '%mor:adv:wh|where det|the n|+n|police+n|man ?']
# ['*CHI:where the policeman ?', '%mor:adv:wh|where det|the n|+n|police+n|man ?']
# ['*MOT:hmm .', '%mor:co|hmm .']
# ['*MOT:where is the policeman ?', '%mor:adv:wh|where v:cop|be&3S det|the n|+n|police+n|man ?']
# ["*CHI:I think he's in there .", '%mor:pro:sub|I v|think pro:sub|he~v:cop|be&3S prep|in adv:loc|there .']
# ['*MOT:maybe here .', '%mor:adv|maybe adv:loc|here .']
# ['*MOT:no no no .', '%mor:co|no co|no co|no .']
# ['*MOT:get out of there .', '%mor:v|get prep|out prep|of adv:loc|there .']
# ['*MOT:hey !', '%mor:co|hey !']
# ['*CHI:xxx policeman not there .', '%mor:n|+n|police+n|man neg|not adv:loc|there .']
# ['*MOT:how about you use this as the policeman ?', '%mor:adv:wh|how prep|about pro|you v|use']
# ['*MOT:okay .', '%mor:co|okay .']
# ["*CHI:okay, but where's his car ?", '%mor:co|okay cm|cm conj|but adv:wh|where~mod|do&3S pro:poss:det|his n|car ?']
# ["*CHI:where's his car ?", '%mor:adv:wh|where~v:cop|be&3S pro:poss:det|his n|car ?']
# ["*MOT:we'll play with the car in a little bit and the policeman car .", '%mor:pro:sub|we~mod|will v|play prep|with det|the n|car prep|in det|a adj|little']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ["*MOT:let's see how big of a tower we can build .", '%mor:v|let~pro|us v|see adv:wh|how adj|big prep|of det|a n|tower']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ['*CHI:xxx we can use the car to knock it down .', '%mor:pro:sub|we aux|can v|use det|the n|car inf|to v|knock pro|it adv:loc|down']
# ['*MOT:yeah, alright .', '%mor:co|yeah cm|cm adj|alright .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:first .', '%mor:adv|first .']
# ['*MOT:we have to build it up .', '%mor:pro:sub|we v|have inf|to v|build pro|it adv:loc|up .']
# ['*CHI:I want it to be xxx .', '%mor:pro:sub|I v|want pro|it inf|to v:cop|be .']
# ['*MOT:alright, put it behind you .', '%mor:co|alright cm|cm v|put&ZERO pro|it prep|behind pro|you .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:now .', '%mor:adv|now .']
# ["*MOT:let's take all the blocks .", '%mor:v|let~pro|us v|take qn|all det|the n|block-PL .']
# ["*MOT:let's build it way up .", '%mor:v|let~pro|us v|build pro|it adv|way prep|up .']
# ["*CHI:hold on, we need to put them in here so we don't lose them .", '%mor:v|hold adv|on cm|cm pro:sub|we v|need inf|to v|put&ZERO pro:obj|them prep|in']
# ['*CHI:then we can .', '%mor:adv:tem|then pro:sub|we aux|can .']
# ['*CHI:we can put them .', '%mor:pro:sub|we aux|can v|put&ZERO pro:obj|them .']
# ['*CHI:we can build .', '%mor:pro:sub|we aux|can v|build .']
# ['*MOT:then we can drive it over here and build it up .', '%mor:adv:tem|then pro:sub|we aux|can v|drive pro|it prep|over adv:loc|here']
# ['*CHI:yup .', '%mor:co|yup .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*MOT:now drive it over here .', '%mor:adv|now v|drive pro|it prep|over adv:loc|here .']
# ['*CHI:beep beep beep beep .', '%mor:n|beep n|beep n|beep n|beep .']
# ['*MOT:alright .', '%mor:unk|xxx . ']
# ['%mor:unk|xxx . ', '%mor:co|alright .']
# ['*MOT:now unload all the blocks .', '%mor:adv|now un#v|load qn|all det|the n|block-PL .']
# ['*CHI:okay !', '%mor:co|okay !']
# ['*CHI:xxx .', '*CHI:xxx .']
# ["*MOT:there's another one .", '%mor:adv:loc|there~v:cop|be&3S qn|another pro:indef|one .']
# ['*MOT:alright Sam, thanks so much .', '%mor:co|alright n:prop|Sam cm|cm v|thank-3S adv:int|so qn|much .']
# ["*CHI:there's three more .", '%mor:adv:loc|there~v:cop|be&3S det:num|three adv|more .']
# ['*MOT:thank you guy .', '%mor:v|thank pro|you n|guy .']
# ['*CHI:one more .', '%mor:det:num|one qn|more .']
# ["*MOT:you're a good guy .", '%mor:pro|you~v:cop|be&PRES det|a adj|good n|guy .']
# ["*MOT:okay, now let's build them all up .", '%mor:co|okay cm|cm adv|now v|let~pro|us v|build pro:obj|them qn|all']
# ['*MOT:xxx up the truck and get it out of the way .', '%mor:prep|up det|the n|truck coord|and v|get pro|it n|out prep|of det|the n|way']
# ['*MOT:okay, move that truck out of the way .', '%mor:co|okay cm|cm v|move det|that v|truck prep|out prep|of det|the n|way']
# ['*MOT:okay come back over here .', '%mor:co|okay v|come n|back prep|over adv:loc|here .']
# ['*MOT:okay, ready ?', '%mor:co|okay cm|cm adj|ready ?']
# ['*MOT:time to build up the block tower .', '%mor:n|time inf|to v|build prep|up det|the n|block n|tower .']
# ['*CHI:yup .', '%mor:co|yup .']
# ['*MOT:then we can knock it down .', '%mor:adv:tem|then pro:sub|we aux|can v|knock pro|it adv:loc|down .']
# ['*CHI:you can .', '%mor:pro|you aux|can .']
# ['*MOT:but we have to build it up first .', '%mor:conj|but pro:sub|we v|have inf|to v|build pro|it adv:loc|up adj|first']
# ['*MOT:I need you to help me .', '%mor:pro:sub|I v|need pro|you inf|to v|help pro:obj|me .']
# ['*MOT:ready ?', '%mor:adj|ready ?']
# ["*MOT:let's do one .", '%mor:v|let~pro|us v|do pro:indef|one .']
# ['*MOT:can you sit over here please ?', '%mor:aux|can pro|you v|sit prep|over adv:loc|here v|please ?']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*MOT:sit over here .', '%mor:v|sit adv:loc|over adv:loc|here .']
# ['*MOT:thank you .', '%mor:v|thank pro|you .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:one two .', '%mor:det:num|one det:num|two .']
# ['*MOT:three four .', '%mor:det:num|three det:num|four .']
# ['*MOT:five six .', '%mor:det:num|five det:num|six .']
# ["*MOT:what's this one ?", '%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?']
# ['*CHI:a train .', '%mor:det|a n|train .']
# ['*MOT:no, what number ?', '%mor:co|no cm|cm pro:wh|what n|number ?']
# ['*MOT:one two three four five six seven .', '%mor:det:num|one det:num|two det:num|three det:num|four det:num|five det:num|six']
# ['*CHI:seven .', '%mor:det:num|seven .']
# ['*MOT:eight .', '%mor:det:num|eight .']
# ['*CHI:eight .', '%mor:det:num|eight .']
# ['*CHI:eight .', '%mor:det:num|eight .']
# ["*MOT:what's this one ?", '%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?']
# ['*CHI:ten .', '%mor:det:num|ten .']
# ['*MOT:nine .', '%mor:det:num|nine .']
# ['*MOT:stop .', '%mor:n|stop .']
# ['*CHI:nine .', '%mor:det:num|nine .']
# ['*MOT:ten .', '%mor:det:num|ten .']
# ['*MOT:what comes after nine ?', '%mor:pro:wh|what v|come-3S prep|after det:num|nine ?']
# ['*CHI:ten eleven twelve thirteen .', '%mor:det:num|ten det:num|eleven det:num|twelve det:num|thirteen .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:okay ready ?', '%mor:co|okay adj|ready ?']
# ['*MOT:you gonna knock it down .', '%mor:pro|you v|go-PROG~inf|to v|knock pro|it adv:loc|down .']
# ['*MOT:ready ?', '%mor:adj|ready ?']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*CHI:here comes the car .', '%mor:adv:loc|here v|come-3S det|the n|car .']
# ['*MOT:alright .', '%mor:co|alright .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ["*MOT:now I'm gonna build one .", '%mor:adv|now pro:sub|I~aux|be&1S v|go-PROG~inf|to v|build pro:indef|one .']
# ['*MOT:okay, ready ?', '%mor:co|okay cm|cm adj|ready ?']
# ["*MOT:we'll look at some books right now buddy .", '%mor:pro:sub|we~mod|will v|look prep|at qn|some n|book-PL adv|right adv|now']
# ['*CHI:no .', '%mor:co|no .']
# ['*MOT:yes .', '%mor:co|yes .']
# ["*CHI:let's look at some books .", '%mor:v|let~pro|us n|look prep|at qn|some n|book-PL .']
# ["*MOT:we'll come back to the car okay .", '%mor:pro:sub|we~mod|will v|come n|back prep|to det|the n|car adj|okay .']
# ["*MOT:we're gonna come back to the car when we're done .", '%mor:pro:sub|we~v:cop|be&PRES v|go-PROG~inf|to v|come n|back prep|to det|the']
# ['*MOT:first we have to play with the books .', '%mor:adv|first pro:sub|we v|have inf|to v|play prep|with det|the n|book-PL']
# ['*CHI:I did not want .', '%mor:pro:sub|I aux|do&PAST neg|not v|want .']
# ["*CHI:I don't want to read the books .", '%mor:pro:sub|I aux|do~neg|not v|want inf|to v|read&ZERO det|the n|book-PL .']
# ['*MOT:just for one minute .', '%mor:adj|just prep|for pro:indef|one n|minute .']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ['*CHI:no .', '%mor:co|no .']
# ['*MOT:yes .', '%mor:co|yes .']
# ['*CHI:no .', '%mor:co|no .']
# ['*MOT:do you want to play with the car again ?', '%mor:aux|do pro|you v|want inf|to v|play prep|with det|the n|car adv|again']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*CHI:I want to knock the tower down .', '%mor:pro:sub|I v|want inf|to v|knock det|the n|tower adv:loc|down .']
# ["*MOT:okay, we can do that as soon as we're done with the books .", '%mor:co|okay cm|cm pro:sub|we aux|can aux|do adv:int|that adv|as adv|soon adv|as']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ['%mor:unk|xxx . ', '*MOT:okay ?']
# ['%mor:co|okay ?', '*CHI:okay .']
# ['%mor:co|okay .', '%mor:unk|xxx . ']
# ["*MOT:come on over and as soon as we're done with the books .", '%mor:v|come adv|on prep|over coord|and conj|as adj|soon adv|as pro:sub|we~aux|be&PRES']
# ['*CHI:xxx .', '*CHI:here .']
# ['%mor:adv:loc|here .', '*CHI:xxx there .']
# ['%mor:adv:loc|there .', '*CHI:xxx .']
# ["*MOT:I don't mean play with them .", '%mor:pro:sub|I aux|do~neg|not adj|mean v|play prep|with pro:obj|them .']
# ['*MOT:we have to read them .', '%mor:pro:sub|we v|have inf|to v|read&ZERO pro:obj|them .']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ['*MOT:which book do you want to read ?', '%mor:rel|which n|book aux|do pro|you v|want inf|to v|read&ZERO ?']
# ['*MOT:which book do you want to read ?', '%mor:rel|which n|book aux|do pro|you v|want inf|to v|read&ZERO ?']
# ['*CHI:I xxx one .', '%mor:unk|xxx . ']
# ['%mor:pro:sub|I pro:indef|one .', '*MOT:which one ?']
# ['%mor:rel|which pro:indef|one ?', '*MOT:this one ?']
# ['%mor:det|this pro:indef|one ?', '*MOT:this one .']
# ['%mor:det|this pro:indef|one .', '*MOT:which one ?']
# ['%mor:rel|which pro:indef|one ?', '*CHI:xxx .']
# ['*MOT:wanna read this one ?', '%mor:v|want~inf|to v|read&ZERO det|this pro:indef|one ?']
# ['*MOT:"How many are there ?"', '%mor:?|"How qn|many v:cop|be&PRES adv:loc|there ?|?"']
# ['*MOT:this one .', '%mor:det|this pro:indef|one .']
# ['*MOT:+" Wiggle_Jiggle Jump_Up+".', '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up+".']
# ['*CHI:yup .', '%mor:co|yup .']
# ['*MOT:okay, come here .', '%mor:co|okay cm|cm v|come adv:loc|here .']
# ['*MOT:come sit on my lap .', '%mor:v|come v|sit prep|on pro:poss:det|my n|lap .']
# ['*MOT:come on .', '%mor:v|come adv:loc|on .']
# ['*CHI:but he wants to .', '%mor:conj|but pro:sub|he v|want-3S prep|to .']
# ['*CHI:he wants to read too .', '%mor:pro:sub|he v|want-3S inf|to v|read&ZERO adv:int|too .']
# ['*MOT:oh great .', '%mor:co|oh adj|great .']
# ["*MOT:that's great .", '%mor:pro:dem|that~v:cop|be&3S adj|great .']
# ['*MOT:come on over here .', '%mor:v|come prep|on prep|over adv:loc|here .']
# ['*MOT:perfect .', '%mor:adj|perfect .']
# ['*MOT:come sit on my lap and then we can all read together .', '%mor:v|come v|sit prep|on pro:poss:det|my n|lap coord|and adv:tem|then pro:sub|we']
# ['*MOT:okay ?', '%mor:co|okay ?']
# ['*MOT:come sit on my lap .', '%mor:v|come v|sit prep|on pro:poss:det|my n|lap .']
# ['*MOT:come on .', '%mor:v|come adv:loc|on .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['%mor:unk|xxx . ', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:+" Wiggle+".']
# ['%mor:n:prop|Wiggle+".', '*MOT:ready ?']
# ['%mor:adj|ready ?', '*MOT:Lester .']
# ['%mor:n:prop|Lester .', '*MOT:+" Wiggle_Jiggle Jump_Up+".']
# ['%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up+".', '*CHI:xxx .']
# ['*MOT:Lester .', '%mor:n:prop|Lester .']
# ['*CHI:okay .', '%mor:co|okay .']
# ["*MOT:where's the dinosaur ?", '%mor:adv:wh|where~v:cop|be&3S det|the n|dinosaur ?']
# ['*MOT:and who is this ?', '%mor:coord|and rel|who v:cop|be&3S det|this ?']
# ['*CHI:a bear .', '%mor:det|a n|bear .']
# ['*MOT:a bear .', '%mor:det|a n|bear .']
# ["*MOT:what's his name ?", '%mor:pro:wh|what~v:cop|be&3S pro:poss:det|his n|name ?']
# ['*MOT:+" Jesse Bear\'s Wiggle_Jiggle Jump_Up +".', '%mor:n:prop|Jesse n:prop|Bear~poss|s n:prop|Wiggle_Jiggle n:prop|Jump_Up +".']
# ["*MOT:what's his name ?", '%mor:pro:wh|what~v:cop|be&3S pro:poss:det|his n|name ?']
# ['*CHI:Wiggle_Jiggle Jump_Up .', '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up .']
# ['*MOT:+" Jesse Bear\'s Wiggle_Jiggle Jump_Up +".', '%mor:n:prop|Jesse n:prop|Bear~poss|s n:prop|Wiggle_Jiggle n:prop|Jump_Up +".']
# ['*MOT:ready ?', '%mor:adj|ready ?']
# ['*MOT:you gonna turn the page with me ?', '%mor:pro|you v|go-PROG~inf|to v|turn det|the n|page prep|with pro:obj|me ?']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*MOT:+" Wiggle_Jiggle Jump_Up silly_willy prance +".', '%mor:n:prop|Wiggle_Jiggle n:prop|Jump_Up ?|silly_willy v|prance +".']
# ['*MOT:what is he doing ?', '%mor:pro:wh|what v:cop|be&3S pro:sub|he part|do-PROG ?']
# ["*CHI:he's jumping on the bed .", '%mor:pro:sub|he~aux|be&3S part|jump-PROG prep|on det|the n|bed .']
# ['*MOT:oh my goodness .', '%mor:co|oh co|my int|goodness .']
# ['*MOT:what happened with this clothes ?', '%mor:pro:wh|what v|happen-PAST prep|with det|this n:pt|clothes ?']
# ['*CHI:he .', '%mor:pro:sub|he .']
# ['*CHI:it just fall off .', '%mor:pro|it adv:int|just v|fall adv|off .']
# ['*MOT:he jumped right off of them xxx .', '%mor:pro:sub|he v|jump-PAST adv|right prep|off prep|of pro:obj|them .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:and what about his dinosaur ?', '%mor:coord|and pro:wh|what prep|about pro:poss:det|his n|dinosaur ?']
# ['*CHI:wait, wait .', '%mor:co|wait cm|cm v|wait .']
# ['*MOT:wait .', '%mor:co|wait .']
# ['*MOT:oh fishie wants to watch too ?', '%mor:co|oh n|fish-DIM v|want-3S inf|to n|watch adv:int|too ?']
# ['*CHI:and all of these .', '%mor:coord|and pro:indef|all prep|of det|these .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*CHI:all of them need to watch .', '%mor:pro:indef|all prep|of pro:obj|them v|need inf|to v|watch .']
# ["*MOT:everybody's watching .", '%mor:pro:indef|everybody~aux|be&3S part|watch-PROG .']
# ["*MOT:that's great .", '%mor:pro:dem|that~v:cop|be&3S adj|great .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*CHI:I can watch too .', '%mor:pro:sub|I aux|can n|watch adv:int|too .']
# ["*MOT:baby's sleeping .", '%mor:n|baby~aux|be&3S part|sleep-PROG .']
# ['*MOT:you ready ?', '%mor:pro|you v|ready ?']
# ["*MOT:let's turn the page .", '%mor:v|let~pro|us v|turn det|the n|page .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*MOT:+" button up the shirt +".', '%mor:n|button prep|up det|the n|shirt +".']
# ['*MOT:who ?', '%mor:rel|who ?']
# ['*MOT:where ?', '%mor:adv:wh|where ?']
# ["*MOT:which picture's got him buttoning up his shirt ?", '%mor:rel|which v|picture~v|have&3S v|get&PAST pro:obj|him adj:part|button-PROG']
# ["*MOT:who's buttoning up his shirt ?", '%mor:rel|who~aux|be&3S part|button-PROG prep|up pro:poss:det|his n|shirt ?']
# ['*CHI:uhm, his dad .', '%mor:?|uhm cm|cm pro:poss:det|his n|dad .']
# ['*MOT:his daddy .', '%mor:pro:poss:det|his n|daddy .']
# ['*MOT:yeah .', '%mor:co|yeah .']
# ['*MOT:look here Lester .', '%mor:n|look adv:loc|here n:prop|Lester .']
# ['*MOT:+"put on the pants+".', '%mor:+"put prep|on det|the ?|pants+".']
# ['*CHI:put on the pants .', '%mor:v|put&ZERO prep|on det|the n:pt|pants .']
# ['*MOT:xxx .', '*MOT:wears his shoes .']
# ['%mor:v|wear-3S pro:poss:det|his n|shoe-PL .', '*CHI:wears his shoes .']
# ['%mor:v|wear-3S pro:poss:det|his n|shoe-PL .', '*MOT:is he doing a good job putting on his pants ?']
# ['%mor:v:cop|be&3S pro:sub|he part|do-PROG det|a adj|good n|job adj:part|put-PROG', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:yeah .']
# ['%mor:co|yeah .', "*CHI:and he's jumping up xxx ."]
# ['%mor:coord|and pro:sub|he~aux|be&3S part|jump-PROG adv:loc|up .', '*MOT:look at this picture .']
# ['%mor:n|look prep|at det|this n|picture .', "*MOT:he's still just wearing his underwear ."]
# ['%mor:pro:sub|he~aux|be&3S adv|still adv:int|just part|wear-PROG pro:poss:det|his', "*MOT:isn't that silly ?"]
# ['%mor:v:cop|be&3S~neg|not pro:dem|that adj|silly ?', '*MOT:+" pull on the socks +".']
# ['%mor:v|pull prep|on det|the n|sock-PL +".', '*MOT:+" tie up the shoes +".']
# ['%mor:n|tie prep|up det|the n|shoe-PL +".', '*MOT:do you put on your own socks ?']
# ['%mor:aux|do pro|you v|put&ZERO prep|on pro:poss:det|your adj|own n|sock-PL', '*CHI:yeah .']
# ['%mor:co|yeah .', '*CHI:and shoes .']
# ['%mor:coord|and n|shoe-PL .', '*MOT:and shoes just like Jesse bear .']
# ['%mor:coord|and n|shoe-PL adv:int|just rel|like n:prop|Jesse n|bear .', '*CHI:hold on, I need to brush his hair .']
# ['%mor:v|hold adv|on cm|cm pro:sub|I v|need inf|to v|brush pro:poss:det|his n|hair', '*MOT:come here .']
# ['%mor:v|come adv:loc|here .', "*MOT:we're not done with this book yet ."]
# ['%mor:unk|xxx . ', '%mor:pro:sub|we~v:cop|be&PRES neg|not adj|done prep|with det|this n|book adv|yet']
# ['*CHI:I need to .', '%mor:pro:sub|I v|need prep|to .']
# ["*MOT:we can do that as soon as we're done .", '%mor:pro:sub|we aux|can aux|do adv:int|that adv|as adv|soon adv|as pro:sub|we~aux|be&PRES']
# ["*CHI:I need to brush the baby's hair .", '%mor:pro:sub|I v|need inf|to v|brush det|the n|baby~poss|s n|hair .']
# ['*MOT:not yet Lester .', '%mor:neg|not adv|yet n:prop|Lester .']
# ['*CHI:xxx .', '*MOT:Lester .']
# ['%mor:n:prop|Lester .', '*CHI:I just wanted the brush .']
# ['%mor:pro:sub|I adv:int|just v|want-PAST det|the n|brush .', '*MOT:oh you wanna hold the brush ?']
# ['%mor:co|oh pro|you v|want~inf|to v|hold det|the n|brush ?', "*MOT:where's the mommy bear ?"]
# ['%mor:adv:wh|where~v:cop|be&3S det|the n|mommy n|bear ?', "*MOT:and where's daddy bear ?"]
# ['%mor:coord|and rel|where~aux|be&3S adj|dad&dn-Y n|bear ?', '*CHI:uhm, xxx .']
# ['%mor:?|uhm cm|cm .', "*MOT:what's daddy bear wearing on the front of himself ?"]
# ['%mor:pro:wh|what~aux|be&3S n|daddy n|bear adj:part|wear-PROG prep|on det|the', '*CHI:his tie .']
# ['%mor:pro:poss:det|his n|tie .', '*MOT:his tie .']
# ['%mor:pro:poss:det|his n|tie .', "*MOT:what's on his tie ?"]
# ['%mor:pro:wh|what~v:cop|be&3S prep|on pro:poss:det|his n|tie ?', '*CHI:bumblebees and honey .']
# ['%mor:n|+n|bumble+n|bee-PL coord|and n|honey .', '*MOT:bumblebees and honey .']
# ['%mor:n|+n|bumble+n|bee-PL coord|and n|honey .', '*MOT:very good .']
# ['%mor:adv:int|very adj|good .', '*MOT:time to turn the page .']
# ['%mor:v|time inf|to v|turn det|the n|page .', '*MOT:+" Jesse dance with me and I\'ll dance with you +".']
# ['%mor:n:prop|Jesse n|dance prep|with pro:obj|me coord|and pro:sub|I~mod|will', "*MOT:who's dancing ?"]
# ['%mor:rel|who~aux|be&3S part|dance-PROG ?', '*CHI:him him him .']
# ['%mor:pro:obj|him pro:obj|him pro:obj|him .', "*MOT:who's this ?"]
# ['%mor:pro:wh|who~v:cop|be&3S pro:dem|this ?', '*CHI:the dad .']
# ['%mor:det|the n|dad .', "*MOT:and who's this ?"]
# ['%mor:coord|and pro:wh|who~v:cop|be&3S pro:dem|this ?', '*CHI:his brother .']
# ['%mor:pro:poss:det|his n|brother .', '*MOT:no .']
# ['%mor:co|no .', '*MOT:who is this ?']
# ['%mor:pro:wh|who v:cop|be&3S det|this ?', '*CHI:his xxx .']
# ['%mor:pro:poss:det|his .', '*MOT:look .']
# ['%mor:n|look .', '*MOT:Jesse .']
# ['%mor:n:prop|Jesse .', "*MOT:and who's this ?"]
# ['%mor:coord|and pro:wh|who~v:cop|be&3S pro:dem|this ?', "*MOT:who's this ?"]
# ['%mor:pro:wh|who~v:cop|be&3S pro:dem|this ?', '*CHI:uhm .']
# ['%mor:?|uhm .', '%mor:unk|xxx . ']
# ["*CHI:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .']
# ["*MOT:you don't know who this is ?", '%mor:pro|you aux|do~neg|not v|know pro:wh|who pro:dem|this v:cop|be&3S ?']
# ['*CHI:no .', '%mor:co|no .']
# ["*MOT:that's the momma bear .", '%mor:pro:dem|that~v:cop|be&3S det|the n|momma n|bear .']
# ['*CHI:hey leave it over there .', '%mor:co|hey n|leave pro|it prep|over adv:loc|there .']
# ["*MOT:Lester you're not xxx .", '%mor:n:prop|Lester pro|you~v:cop|be&PRES neg|not .']
# ['*CHI:xxx .', "*MOT:now we have to read another book cause you didn't ."]
# ['%mor:adv|now pro:sub|we v|have inf|to v|read&ZERO qn|another n|book v|cause', '*CHI:no .']
# ['%mor:co|no .', '*MOT:oh .']
# ['%mor:co|oh .', "*CHI:I don't want to read another book ."]
# ['%mor:pro:sub|I aux|do~neg|not v|want inf|to v|read&ZERO qn|another n|book .', '*MOT:Lester, look what I have in here .']
# ['%mor:n:prop|Lester cm|cm v|look pro:wh|what pro:sub|I v|have prep|in adv:loc|here', '*MOT:you can have some .']
# ['%mor:pro|you aux|can v|have qn|some .', '*MOT:stay here with me .']
# ['%mor:v|stay adv:loc|here prep|with pro:obj|me .', '*MOT:oh .']
# ['%mor:co|oh .', '*INV1:just one .']
# ['%mor:adj|just pro:indef|one .', '*MOT:just one piece .']
# ['%mor:adv:int|just det:num|one n|piece .', '*MOT:one .']
# ['%mor:pro:indef|one .', '*MOT:which color are you going to pick ?']
# ['%mor:rel|which n|color aux|be&PRES pro|you part|go-PROG inf|to v|pick ?', '*MOT:just one .']
# ['%mor:adj|just pro:indef|one .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:now we have to put the top back on .']
# ['%mor:adv|now pro:sub|we v|have inf|to v|put&ZERO det|the n|top adv:loc|back', '*CHI:I can do that .']
# ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:wait a second !']
# ['%mor:v|wait det|a n|second !', '*CHI:I can do that .']
# ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:let me see this .']
# ['%mor:v|let&ZERO pro:obj|me v|see det|this .', '*CHI:I can do that .']
# ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:wait .']
# ['%mor:co|wait .', '*MOT:just a minute .']
# ['%mor:adv:int|just det|a n|minute .', '*MOT:we have to follow directions .']
# ['%mor:pro:sub|we v|have inf|to v|follow n|direction-PL .', '*CHI:I can do that .']
# ['%mor:pro:sub|I aux|can v|do pro:dem|that .', '*MOT:you gonna put the top on ?']
# ['%mor:unk|xxx . ', '%mor:pro|you v|go-PROG~inf|to v|put&ZERO det|the adj|top adv|on ?']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:put the top on .', '%mor:v|put&ZERO det|the adj|top adv|on .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:put it on .', '%mor:v|put&ZERO pro|it adv:loc|on .']
# ['*MOT:okay, now look what I have .', '%mor:co|okay cm|cm adv|now v|look pro:wh|what pro:sub|I v|have .']
# ['*MOT:look what I have .', '%mor:v|look pro:wh|what pro:sub|I v|have .']
# ['*CHI:xxx .', '*MOT:which one do you want ?']
# ['%mor:rel|which pro:indef|one v|do pro|you v|want ?', '*MOT:which one do you want ?']
# ['%mor:rel|which pro:indef|one v|do pro|you v|want ?', '*MOT:yeah ?']
# ['%mor:co|yeah ?', '%mor:unk|xxx . ']
# ['*MOT:why do you want this one ?', '%mor:adv:wh|why aux|do pro|you v|want det|this pro:indef|one ?']
# ['*CHI:because I want to put it in the school bus .', '%mor:conj|because pro:sub|I v|want inf|to v|put&ZERO pro|it prep|in det|the']
# ['*MOT:because you want to put it in the school bus .', '%mor:conj|because pro|you v|want inf|to v|put&ZERO pro|it prep|in det|the n|school']
# ['*MOT:do you want another piece ?', '%mor:aux|do pro|you v|want qn|another n|piece ?']
# ['*CHI:no .', '%mor:co|no .']
# ['*MOT:no .', '%mor:co|no .']
# ['*CHI:xxx .', '*MOT:do you want the empty one ?']
# ['%mor:v|do pro|you v|want det|the adj|empty pro:indef|one ?', '*CHI:sure .']
# ['%mor:adj|sure .', '*MOT:okay .']
# ['%mor:unk|xxx . ', '%mor:co|okay .']
# ['*CHI:xxx put in .', '%mor:v|put&ZERO adv:loc|in .']
# ['*MOT:what are you gonna do with that one ?', '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with det|that']
# ['*CHI:maybe we can put in skittles .', '%mor:adv|maybe pro:sub|we aux|can v|put&ZERO prep|in n|skittle-PL .']
# ['*MOT:maybe we can put in skittles .', '%mor:adv|maybe pro:sub|we aux|can v|put&ZERO prep|in n|skittle-PL .']
# ['*MOT:put one in each one ?', '%mor:v|put&ZERO pro:indef|one prep|in qn|each pro:indef|one ?']
# ['*MOT:ooh look at that .', '%mor:co|ooh v|look prep|at det|that .']
# ['*CHI:xxx .', '*MOT:look what I have now .']
# ['%mor:v|look pro:wh|what pro:sub|I aux|have adv|now .', '*MOT:what is this ?']
# ['%mor:pro:wh|what v:cop|be&3S det|this ?', '*CHI:a balloon pumper .']
# ['%mor:det|a n|balloon n|pump&dv-AGT .', '*MOT:a balloon pumper .']
# ['%mor:det|a n|balloon n|pump&dv-AGT .', '*CHI:yeah, I want to try it .']
# ['%mor:co|yeah cm|cm pro:sub|I v|want inf|to v|try pro|it .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:no, mommy first .']
# ['%mor:co|no cm|cm n|mommy adv|first .', "*MOT:I'm gonna do ."]
# ['%mor:pro:sub|I~aux|be&1S v|go-PROG~inf|to v|do .', "*MOT:look what I'm gonna do ."]
# ['%mor:v|look pro:wh|what pro:sub|I~aux|be&1S v|go-PROG~inf|to v|do .', '*MOT:ready ?']
# ['%mor:adj|ready ?', '*MOT:let mommy do it first .']
# ['%mor:v|let&ZERO n|mommy v|do pro|it adv|first .', '*INV1:then you press the trigger after you .']
# ['%mor:adv:tem|then pro|you v|press det|the n|trigger prep|after pro|you .', '*MOT:oh .']
# ['%mor:co|oh .', '*INV1:pump it .']
# ['%mor:v|pump pro|it .', '*INV2:yeah, then it blows by itself .']
# ['%mor:co|yeah cm|cm adv:tem|then pro|it v|blow-3S prep|by pro:refl|itself .', '*MOT:oh .']
# ['%mor:co|oh .', '*MOT:cool .']
# ['%mor:adj|cool .', '*INV2:I discovered it recently .']
# ['%mor:pro:sub|I v|discover-PAST pro|it adv|recent&dadj-LY .', '*CHI:woah, tie it .']
# ['%mor:int|woah cm|cm v|tie pro|it .', '*CHI:tie it .']
# ['%mor:v|tie pro|it .', '*MOT:okay, ready ?']
# ['%mor:co|okay cm|cm adj|ready ?', '*MOT:what am I gonna do ?']
# ['%mor:pro:wh|what v:cop|be&1S pro:sub|I v|go-PROG~inf|to v|do ?', '*CHI:tie it .']
# ['%mor:v|tie pro|it .', "*MOT:where'd it go ?"]
# ['%mor:rel|where~mod|genmod pro|it v|go ?', '*MOT:where did it go ?']
# ['%mor:adv:wh|where v|do&PAST pro|it v|go ?', '*MOT:over here .']
# ['%mor:prep|over adv:loc|here .', '*CHI:xxx over here .']
# ['%mor:prep|over adv:loc|here .', "*CHI:now it's my turn ."]
# ['%mor:adv|now pro|it~v:cop|be&3S pro:poss:det|my n|turn .', '*MOT:your turn .']
# ['%mor:pro:poss:det|your n|turn .', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:so what do you do ?']
# ['%mor:co|so pro:wh|what aux|do pro|you v|do ?', '*CHI:can you hold it ?']
# ['%mor:aux|can pro|you v|hold pro|it ?', '*CHI:and I pump it .']
# ['%mor:coord|and pro:sub|I v|pump pro|it .', '*MOT:okay, ready ?']
# ['%mor:co|okay cm|cm adj|ready ?', '*CHI:do it .']
# ['%mor:v|do pro|it .', "*MOT:stop, don't pump ."]
# ['%mor:n|stop cm|cm aux|do~neg|not n|pump .', '%mor:unk|xxx . ']
# ['*MOT:you gotta wait till it fills .', '%mor:pro|you v|get&PAST~inf|to co|wait v|till pro|it v|fill-3S .']
# ['*MOT:pump just a little bit more .', '%mor:n|pump adv:int|just det|a adj|little n|bit qn|more .']
# ["*MOT:okay, that's it .", '%mor:co|okay cm|cm pro:dem|that~v:cop|be&3S pro|it .']
# ["*CHI:it's a .", '%mor:pro|it~v:cop|be&3S det|a .']
# ["*CHI:it's a pear .", '%mor:pro|it~v:cop|be&3S det|a n|pear .']
# ['*MOT:it looks like a pear .', '%mor:pro|it v|look-3S prep|like det|a n|pear .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*CHI:tie it .', '%mor:v|tie pro|it .']
# ['*CHI:xxx .', '*MOT:oh .']
# ['%mor:co|oh .', '*CHI:do you want a skittle ?']
# ['%mor:aux|do pro|you v|want det|a n|skittle ?', '*MOT:uh, no thanks .']
# ['%mor:co|uh cm|cm co|no co|thanks .', '*MOT:thank you for asking, I appretiate it .']
# ['%mor:v|thank pro|you prep|for n:gerund|ask-PROG cm|cm pro:sub|I ?|appretiate', '*INV1:do one more of the xxx .']
# ['%mor:v|do pro:indef|one qn|more prep|of det|the .', '*MOT:okay .']
# ['%mor:co|okay .', "*MOT:you're gonna hold it, okay ?"]
# ['%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v|hold pro|it cm|cm adj|okay ?', "*CHI:it's just like a balloon ."]
# ['%mor:pro|it~v:cop|be&3S adv:int|just prep|like det|a n|balloon .', '*MOT:it is a balloon .']
# ['%mor:pro|it v:cop|be&3S det|a n|balloon .', "*MOT:it's not just like a balloon ."]
# ['%mor:pro|it~v:cop|be&3S neg|not adv:int|just prep|like det|a n|balloon .', '*MOT:it is a balloon .']
# ['%mor:unk|xxx . ', '%mor:pro|it v:cop|be&3S det|a n|balloon .']
# ['*CHI:can we tie it ?', '%mor:aux|can pro:sub|we v|tie pro|it ?']
# ['*CHI:can we tie it ?', '%mor:aux|can pro:sub|we v|tie pro|it ?']
# ["*MOT:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .']
# ["*MOT:there aren't our balloons .", '%mor:adv:loc|there aux|be&PRES~neg|not pro:poss:det|our n|balloon-PL .']
# ['*CHI:can we tie this ?', '%mor:aux|can pro:sub|we v|tie det|this ?']
# ["*INV1:we'll do it at the end .", '%mor:pro:sub|we~mod|will aux|do pro|it prep|at det|the n|end .']
# ["*MOT:how's that ?", '%mor:adv:wh|how~aux|be&3S pro:dem|that ?']
# ['*MOT:oh .', '%mor:unk|xxx . ']
# ['%mor:co|oh .', '*CHI:xxx .']
# ['*MOT:alright, come sit down again .', '%mor:co|alright cm|cm v|come v|sit adv:loc|down adv|again .']
# ['*CHI:got it .', '%mor:v|get&PAST pro|it .']
# ['*MOT:alright .', '%mor:co|alright .']
# ['*MOT:here, let me hold on to this .', '%mor:adv:loc|here cm|cm v|let&ZERO pro:obj|me v|hold prep|on prep|to pro:dem|this']
# ["*MOT:I'll hold on to this .", '%mor:pro:sub|I~mod|will v|hold prep|on prep|to pro:dem|this .']
# ["*MOT:we'll do this when we're done .", '%mor:pro:sub|we~mod|will v|do det|this conj|when pro:sub|we~aux|be&PRES adj|done']
# ["*CHI:I'll do it .", '%mor:pro:sub|I~mod|will aux|do pro|it .']
# ['*CHI:xxx .', "*MOT:when we're done ."]
# ['%mor:conj|when pro:sub|we~v:cop|be&PRES adj|done .', "*MOT:when we're done ."]
# ['%mor:conj|when pro:sub|we~v:cop|be&PRES adj|done .', '*MOT:first .']
# ['%mor:adv|first .', '*MOT:look Lester, look what I have now .']
# ['%mor:v|look n:prop|Lester cm|cm v|look pro:wh|what pro:sub|I aux|have adv|now', '*MOT:wait .']
# ['%mor:co|wait .', '*MOT:let me see .']
# ['%mor:v|let&ZERO pro:obj|me v|see .', '*CHI:I want to hold it .']
# ['%mor:pro:sub|I v|want inf|to v|hold pro|it .', "*MOT:alright, you're gonna hold it ?"]
# ['%mor:co|alright cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|hold pro|it ?', "*MOT:that's it ."]
# ['%mor:pro:dem|that~v:cop|be&3S pro|it .', '*MOT:just hold it .']
# ['%mor:adv:int|just v|hold pro|it .', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:look what I have now .']
# ['%mor:v|look pro:wh|what pro:sub|I aux|have adv|now .', '*MOT:look at the toys that I have .']
# ['%mor:v|look prep|at det|the n|toy-PL rel|that pro:sub|I v|have .', '*CHI:can I see ?']
# ['%mor:aux|can pro:sub|I v|see ?', '*CHI:a magic wand .']
# ['%mor:det|a adj|magic n|wand .', '*MOT:a magic wand .']
# ['%mor:det|a adj|magic n|wand .', '*MOT:oh .']
# ['%mor:co|oh .', '*CHI:snake .']
# ['%mor:n|snake .', '*MOT:a snake .']
# ['%mor:det|a n|snake .', '*MOT:oh .']
# ['%mor:co|oh .', '*MOT:what is that ?']
# ['%mor:pro:wh|what v:cop|be&3S pro:dem|that ?', '*CHI:an elephant .']
# ['%mor:det|a n|elephant .', '*MOT:elephant .']
# ['%mor:n|elephant .', '*MOT:oh .']
# ['%mor:co|oh .', '*CHI:glasses .']
# ['%mor:n|glass-PL .', '*CHI:a car .']
# ['%mor:det|a n|car .', '*MOT:cool car .']
# ['%mor:adj|cool n|car .', '*MOT:the doors open .']
# ['%mor:det|the n|door-PL adv|open .', '*MOT:those are pretty neat huh ?']
# ['%mor:pro:dem|those v:cop|be&PRES adv:int|pretty adj|neat co|huh ?', '*INV1:xxx .']
# ["*MOT:there's two more toys .", '%mor:adv:loc|there~v:cop|be&3S det:num|two adv|more v|toy-3S .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*CHI:these are elephants .', '%mor:pro:dem|these v:cop|be&PRES n|elephant-PL .']
# ['*MOT:alright .', '%mor:co|alright .']
# ['*CHI:this is the baby elephant .', '%mor:pro:dem|this v:cop|be&3S det|the adj|babe&dn-Y n|elephant .']
# ["*CHI:that's the .", '%mor:pro:dem|that~v:cop|be&3S det|the .']
# ['*MOT:which elephant is this ?', '%mor:rel|which n|elephant v:cop|be&3S det|this ?']
# ['*CHI:a bigger one .', '%mor:det|a adj|big-CP pro:indef|one .']
# ['*CHI:this is the baby one .', '%mor:pro:dem|this v:cop|be&3S det|the n|baby pro:indef|one .']
# ["*CHI:that's his sister one .", '%mor:pro:dem|that~v:cop|be&3S pro:poss:det|his n|sister pro:indef|one .']
# ['*MOT:oh very nice .', '%mor:co|oh adv:int|very adj|nice .']
# ['*MOT:where are they gonna go ?', '%mor:adv:wh|where v:cop|be&PRES pro:sub|they v|go-PROG~inf|to v|go ?']
# ['*CHI:to the school bus .', '%mor:prep|to det|the n|school n|bus .']
# ['*CHI:a elephant school bus .', '%mor:det|a n|elephant n|school n|bus .']
# ['*MOT:the elephant school bus .', '%mor:det|the n|elephant n|school n|bus .']
# ['*MOT:oh, stop .', '%mor:co|oh cm|cm n|stop .']
# ['*MOT:time to let the elephants on .', '%mor:n|time inf|to v|let&ZERO det|the n|elephant-PL adv|on .']
# ['*MOT:open the door .', '%mor:v|open det|the n|door .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:which elephant goes first ?', '%mor:rel|which n|elephant v|go-3S adv|first ?']
# ['*CHI:baby one .', '%mor:adj|babe&dn-Y pro:indef|one .']
# ['*MOT:and what do elephants say ?', '%mor:coord|and pro:wh|what v|do n|elephant-PL v|say ?']
# ["*MOT:wow, that's pretty cool .", '%mor:co|wow cm|cm pro:dem|that~v:cop|be&3S adv:int|pretty adj|cool .']
# ['*MOT:how do they say it ?', '%mor:adv:wh|how v|do pro:sub|they v|say pro|it ?']
# ['*MOT:how do they say that ?', '%mor:adv:wh|how v|do pro:sub|they v|say rel|that ?']
# ['*CHI:with their trunks .', '%mor:prep|with pro:poss:det|their n|trunk-PL .']
# ['*MOT:with their trunks .', '%mor:prep|with pro:poss:det|their n|trunk-PL .']
# ['*CHI:they put the suitcase at the back .', '%mor:pro:sub|they v|put&ZERO det|the n|suitcase prep|at det|the n|back .']
# ['*MOT:put the suitcase in the back .', '%mor:v|put&ZERO det|the n|suitcase prep|in det|the n|back .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ["*MOT:that's very smart .", '%mor:pro:dem|that~v:cop|be&3S adv:int|very adj|smart .']
# ['*MOT:which elephant goes next ?', '%mor:rel|which n|elephant v|go-3S adv|next ?']
# ['*CHI:this one .', '%mor:det|this pro:indef|one .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:and then last but not least .', '%mor:coord|and adv:tem|then n|last conj|but neg|not adj|least .']
# ['*MOT:oh, mommy might need to go in the top .', '%mor:co|oh cm|cm n|mommy aux|might v|need inf|to v|go prep|in det|the n|top']
# ['*MOT:there we go .', '%mor:adv:loc|there pro:sub|we v|go .']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*CHI:where the school ?', '%mor:adv:wh|where det|the n|school ?']
# ['*MOT:xxx .', '*CHI:there goes xxx .']
# ['%mor:adv:loc|there v|go-3S .', '*MOT:xxx wants to .']
# ['%mor:v|want-3S prep|to .', '*MOT:alright, you wanna play with the remote control car again ?']
# ['%mor:co|alright cm|cm pro|you v|want~inf|to v|play prep|with det|the adj|remote', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:yeah .']
# ['%mor:co|yeah .', '*MOT:alright .']
# ['%mor:co|alright .', '*CHI:and the balloon pumper .']
# ['%mor:coord|and det|the n|balloon n|pump&dv-AGT .', '*MOT:and the balloon pumper .']
# ['%mor:coord|and det|the n|balloon n|pump&dv-AGT .', '*CHI:yeah, you can .']
# ['%mor:co|yeah cm|cm pro|you aux|can .', '*CHI:I can do car, you can do the balloon pumper .']
# ['%mor:pro:sub|I aux|can v|do n|car cm|cm pro|you aux|can v|do det|the n|balloon', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:that sounds great to me .']
# ['%mor:det|that adj|sound-PL adj|great prep|to pro:obj|me .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:so where are you gonna go with the car ?']
# ['%mor:co|so rel|where aux|be&PRES pro|you v|go-PROG~inf|to v|go prep|with det|the', '*MOT:woah, get the bus out of the way ?']
# ['%mor:int|woah cm|cm v|get det|the n|bus prep|out prep|of det|the n|way ?', '*MOT:oh .']
# ['%mor:co|oh .', '*MOT:oh my goodness .']
# ['%mor:co|oh co|my int|goodness .', '*CHI:make it big .']
# ['%mor:v|make pro|it adj|big .', '*MOT:are we done playing with the car already ?']
# ['%mor:v:cop|be&PRES pro:sub|we adj|done adj:part|play-PROG prep|with det|the', '*CHI:no .']
# ['%mor:co|no .', "*MOT:well why don't you do the car and I'll do the balloon ."]
# ['%mor:co|well adv:wh|why aux|do~neg|not pro|you v|do det|the n|car coord|and', '*MOT:okay ?']
# ['%mor:co|okay ?', '*CHI:okay .']
# ['%mor:co|okay .', '*MOT:alright, where is it gonna go next ?']
# ['%mor:co|alright cm|cm rel|where aux|be&3S pro|it v|go-PROG~inf|to v|go adv|next', '*MOT:woah, woah, woah .']
# ['%mor:int|woah cm|cm int|woah cm|cm int|woah .', "*CHI:it's gonna go there ."]
# ['%mor:pro|it~aux|be&3S v|go-PROG~inf|to v|go adv:loc|there .', '*MOT:there we go .']
# ['%mor:adv:loc|there pro:sub|we v|go .', '*MOT:xxx forward silly .']
# ['%mor:adj|forward adj|silly .', '*MOT:ah, crash .']
# ['%mor:co|ah cm|cm n|crash .', '*MOT:crashed into everybody .']
# ['%mor:v|crash-PAST prep|into pro:indef|everybody .', '*MOT:run over those poor kids .']
# ['%mor:v|run prep|over det|those adj|poor n|kid-PL .', '*MOT:oh my goodness .']
# ['%mor:co|oh co|my int|goodness .', '*MOT:ah .']
# ['%mor:co|ah .', '*MOT:you ran the mommy .']
# ['%mor:pro|you v|run&PAST det|the n|mommy .', '*MOT:here we go, go, go .']
# ['%mor:adv:loc|here pro:sub|we v|go cm|cm v|go cm|cm v|go .', '*MOT:ah, you ran into Lester .']
# ['%mor:co|ah cm|cm pro|you v|run&PAST prep|into n:prop|Lester .', '*MOT:think you can run over the balloon ?']
# ['%mor:v|think pro|you aux|can v|run prep|over det|the n|balloon ?', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:think you can run over the balloon ?']
# ['%mor:v|think pro|you aux|can v|run prep|over det|the n|balloon ?', '*MOT:oh, wrong way .']
# ['%mor:co|oh cm|cm adj|wrong n|way .', '*MOT:ah, almost .']
# ['%mor:co|ah cm|cm adv|almost .', '*CHI:I want to try it .']
# ['%mor:pro:sub|I v|want inf|to v|try pro|it .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:oh, okay .']
# ['%mor:co|oh cm|cm adj|okay .', "*CHI:let's do a different balloon ."]
# ['%mor:v|let~pro|us v|do det|a adj|different n|balloon .', '*CHI:xxx here .']
# ['%mor:adv:loc|here .', '*MOT:okay .']
# ['%mor:co|okay .', '*MOT:no, no .']
# ['%mor:co|no cm|cm co|no .', "*MOT:we'll do more balloons later ."]
# ['%mor:pro:sub|we~mod|will v|do qn|more n|balloon-PL adv|later .', "*MOT:let's ."]
# ['%mor:v|let~pro|us .', '*MOT:what do you wanna do next ?']
# ['%mor:pro:wh|what aux|do pro|you v|want~inf|to v|do adv|next ?', '*MOT:do you want .']
# ['%mor:aux|do pro|you v|want .', '*MOT:stop .']
# ['%mor:n|stop .', '*MOT:do you want to say, build a tower ?']
# ['%mor:v|do pro|you v|want inf|to v|say cm|cm v|build det|a n|tower ?', '*CHI:no, I want to xxx .']
# ['%mor:co|no cm|cm pro:sub|I v|want prep|to .', '*MOT:xxx with the car .']
# ['%mor:prep|with det|the n|car .', "*MOT:what's the car doing ?"]
# ['%mor:pro:wh|what~aux|be&3S det|the n|car adj:part|do-PROG ?', "*CHI:it's scratchy ."]
# ['%mor:pro|it~v:cop|be&3S adj|scratch&dn-Y .', "*MOT:it's what ?"]
# ...
# ['%mor:pro:poss:det|his n|head .', '*MOT:okay, be very gentle with the baby .']
# ['%mor:co|okay cm|cm aux|be adv:int|very adj|gentle prep|with det|the n|baby', "*CHI:okay, he's little ."]
# ['%mor:co|okay cm|cm pro:sub|he~v:cop|be&3S adj|little .', '*MOT:yes, he is little .']
# ['%mor:co|yes cm|cm pro:sub|he v:cop|be&3S adj|little .', '*MOT:what else do you dry on the baby ?']
# ['%mor:pro:wh|what post|else v|do pro|you v|dry prep|on det|the n|baby ?', '*CHI:everything .']
# ['%mor:pro:indef|everything .', '*MOT:everything ?']
# ['%mor:pro:indef|everything ?', '*MOT:like what ?']
# ['%mor:prep|like pro:wh|what ?', '*CHI:now we need to give him a pillow .']
# ['%mor:adv|now pro:sub|we v|need inf|to v|give pro:obj|him det|a n|pillow .', "*MOT:and then what do you do with the baby's hair when you're done"]
# ['%mor:coord|and adv:tem|then pro:wh|what aux|do pro|you v|do prep|with det|the', '*CHI:uhm, you just brush his baby hair .']
# ['%mor:?|uhm cm|cm pro|you adv:int|just v|brush pro:poss:det|his n|baby n|hair', '*MOT:very nice .']
# ['%mor:adv:int|very adj|nice .', '*MOT:are you gonna feed the baby ?']
# ['%mor:aux|be&PRES pro|you v|go-PROG~inf|to v|feed det|the n|baby ?', '*MOT:Lester, are you gonna feed the baby ?']
# ['%mor:n:prop|Lester cm|cm aux|be&PRES pro|you v|go-PROG~inf|to v|feed det|the', '*CHI:okay .']
# ['%mor:co|okay .', '*MOT:what do you feed him ?']
# ['%mor:pro:wh|what aux|do pro|you v|feed pro:obj|him ?', '*MOT:you should probably feed the baby from the containers .']
# ['%mor:pro|you aux|should adv|probable&dadj-LY v|feed det|the n|baby prep|from', '*MOT:from the baby food containers .']
# ['%mor:prep|from det|the n|baby n|food n|contain&dv-AGT-PL .', "*MOT:oh, you're a good opener ."]
# ['%mor:co|oh cm|cm pro|you~v:cop|be&PRES det|a adj|good n|open&dv-AGT .', '*MOT:oh, baby eats skittles .']
# ['%mor:co|oh cm|cm n|baby v|eat-3S n|skittle-PL .', "*MOT:I don't think so ."]
# ['%mor:pro:sub|I aux|do~neg|not v|think co|so .', "*MOT:baby's don't have teeth ."]
# ['%mor:n|baby~poss|s aux|do~neg|not v|have n|tooth&PL .', "*MOT:you didn't feed the baby ."]
# ['%mor:pro|you aux|do&PAST~neg|not v|feed det|the n|baby .', '*MOT:gotta use the spoon .']
# ['%mor:v|get&PAST~inf|to v|use det|the n|spoon .', '*MOT:to feed the baby .']
# ['%mor:inf|to v|feed det|the n|baby .', '*CHI:I just did .']
# ['%mor:pro:sub|I adv:int|just v|do&PAST .', '*MOT:what kind of food did you feed the baby ?']
# ['%mor:pro:wh|what n|kind prep|of n|food v|do&PAST pro|you v|feed det|the n|baby', '*CHI:some shampoo .']
# ['%mor:qn|some n|shampoo .', '*MOT:some shampoo ?']
# ['%mor:qn|some n|shampoo ?', '*MOT:oh .']
# ['%mor:co|oh .', '%mor:unk|xxx . ']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ["*MOT:babies don't eat shampoo .", '%mor:n|baby-PL aux|do~neg|not v|eat n|shampoo .']
# ['*MOT:what do babies eat ?', '%mor:det:wh|what v|do n|baby-PL v|eat ?']
# ["*MOT:that's so silly .", '%mor:pro:dem|that~v:cop|be&3S adv:int|so adj|silly .']
# ['%mor:unk|xxx . ', '*MOT:what are you doing with the car ?']
# ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG prep|with det|the n|car ?', '*CHI:back it up .']
# ['%mor:adv:loc|back pro|it adv:loc|up .', '*MOT:backing it up ?']
# ['%mor:adj:part|back-PROG pro|it adv:loc|up ?', '*MOT:now what ?']
# ['%mor:adv|now pro:wh|what ?', "*MOT:ah, you're gonna run the poor baby over ."]
# ['%mor:co|ah cm|cm pro|you~aux|be&PRES v|go-PROG~inf|to v|run det|the adj|poor', '*CHI:xxx .']
# ['*MOT:what letter is this ?', '%mor:pro:wh|what n|letter v:cop|be&3S det|this ?']
# ['*CHI:k@l .', '%mor:n:let|k .']
# ['*MOT:what number is this ?', '%mor:pro:wh|what n|number v:cop|be&3S det|this ?']
# ['*CHI:uhm, five .', '%mor:?|uhm cm|cm det:num|five .']
# ['*CHI:xxx .', '*MOT:alright, what letters are these ?']
# ['%mor:co|alright cm|cm pro:wh|what n|letter-PL v:cop|be&PRES det|these ?', '*MOT:Lester, what letter is this ?']
# ['%mor:n:prop|Lester cm|cm pro:wh|what n|letter v:cop|be&3S det|this ?', '*CHI:e@l, b@l, j@l, y@l .']
# ['%mor:n:let|e cm|cm n:let|b cm|cm n:let|j cm|cm n:let|y .', '*MOT:and this ?']
# ['%mor:coord|and pro:dem|this ?', '*CHI:a@l .']
# ['%mor:n:let|a .', "*MOT:what's this ?"]
# ['%mor:pro:wh|what~v:cop|be&3S pro:dem|this ?', '*CHI:uhm, xxx .']
# ['%mor:?|uhm cm|cm .', '*CHI:f@l .']
# ['%mor:n:let|f .', '*CHI:I cannot do everything .']
# ['%mor:pro:sub|I aux|can~neg|not v|do pro:indef|everything .', "*MOT:what's this one ?"]
# ['%mor:pro:wh|what~aux|be&3S det|this pro:indef|one ?', '*CHI:I want this xxx .']
# ['%mor:pro:sub|I v|want det|this .', '*CHI:like this .']
# ['%mor:prep|like pro:dem|this .', '*MOT:you want the what part ?']
# ['%mor:pro|you v|want det|the pro:wh|what n|part ?', '*CHI:this .']
# ['%mor:det|this .', '*MOT:what is that ?']
# ['%mor:pro:wh|what v:cop|be&3S pro:dem|that ?', "*CHI:it's a balloon pumper ."]
# ['%mor:pro|it~v:cop|be&3S det|a n|balloon n|pump&dv-AGT .', "*MOT:it's a balloon pumper ."]
# ['%mor:pro|it~v:cop|be&3S det|a n|balloon n|pump&dv-AGT .', '*CHI:yeah .']
# ['%mor:co|yeah .', '*MOT:can you say balloon pumper .']
# ['%mor:aux|can pro|you co|say n|balloon n|pump&dv-AGT .', '*CHI:balloon pumper .']
# ['%mor:n|balloon n|pump&dv-AGT .', '*MOT:look at my mouth please .']
# ['%mor:n|look prep|at pro:poss:det|my n|mouth v|please .', '*MOT:balloon .']
# ['%mor:n|balloon .', '*CHI:balloon .']
# ['%mor:n|balloon .', '*MOT:balloon .']
# ['%mor:n|balloon .', '*CHI:I just said that .']
# ['%mor:pro:sub|I adv:int|just v|say&PAST rel|that .', '*MOT:look at me .']
# ['%mor:n|look prep|at pro:obj|me .', '*CHI:balloon pumper .']
# ['%mor:n|balloon n|pump&dv-AGT .', '*MOT:very close .']
# ['%mor:adv:int|very adj|close .', '*MOT:look at me buddy .']
# ['%mor:n|look prep|at pro:obj|me n|buddy .', '*CHI:can you xxx .']
# ['%mor:aux|can pro|you .', '*MOT:what are you doing ?']
# ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?', '*MOT:what are you doing ?']
# ['%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?', "*CHI:uhm, I'm doing this ."]
# ['%mor:?|uhm cm|cm pro:sub|I~aux|be&1S part|do-PROG det|this .', "*CHI:I'm making a balloon ."]
# ['%mor:pro:sub|I~aux|be&1S part|make-PROG det|a n|balloon .', '*MOT:what color is the balloon ?']
# ['%mor:pro:wh|what n|color v:cop|be&3S det|the n|balloon ?', '*CHI:red .']
# ['%mor:adj|red .', '*MOT:okay, stop pumping .']
# ['%mor:co|okay cm|cm n|stop adj:part|pump-PROG .', '*CHI:okay, now .']
# ['%mor:unk|xxx . ', '%mor:co|okay cm|cm adv|now .']
# ['*MOT:okay, stop pumping .', '%mor:co|okay cm|cm n|stop adj:part|pump-PROG .']
# ["*MOT:what's gonna happen when the balloon is all filled up ?", '%mor:pro:wh|what~aux|be&3S v|go-PROG~inf|to v|happen conj|when det|the n|balloon']
# ["*CHI:it's going to explode .", '%mor:pro|it~aux|be&3S part|go-PROG inf|to v|explode .']
# ['*MOT:explode .', '%mor:v|explode .']
# ["*MOT:okay, that's enough .", '%mor:co|okay cm|cm rel|that~aux|be&3S adv|enough .']
# ["*MOT:alright, that's big enough .", '%mor:co|alright cm|cm pro:dem|that~v:cop|be&3S adj|big adv|enough .']
# ['*MOT:what are you gonna do with it now ?', '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with pro|it']
# ["*MOT:snake's eating your toe .", '%mor:n|snake~aux|be&3S part|eat-PROG pro:poss:det|your n|toe .']
# ['*CHI:ah .', '%mor:co|ah .']
# ['*CHI:xxx .', "*MOT:here, let's play with this one ."]
# ['%mor:adv:loc|here cm|cm v|let~pro|us v|play prep|with det|this pro:indef|one', "*MOT:we haven't playing with this one at all ."]
# ['%mor:pro:sub|we aux|have~neg|not part|play-PROG prep|with det|this pro:indef|one', '*MOT:xxx .']
# ['%mor:unk|xxx . ', "*MOT:let's see ."]
# ['%mor:v|let~pro|us co|see .', '*MOT:what is this ?']
# ['%mor:pro:wh|what v:cop|be&3S det|this ?', '*CHI:a clown .']
# ['%mor:det|a n|clown .', '*MOT:are they all clowns ?']
# ['%mor:v:cop|be&PRES pro:sub|they adv:int|all n|clown-PL ?', "*MOT:what's that one ?"]
# ['%mor:pro:wh|what~aux|be&3S det|that pro:indef|one ?', '*CHI:ah xxx .']
# ['%mor:co|ah .', '*MOT:and that one ?']
# ['%mor:coord|and rel|that pro:indef|one ?', '*CHI:a tiger .']
# ['%mor:det|a n|tiger .', '*CHI:and a clown .']
# ['%mor:coord|and det|a n|clown .', '*CHI:and a xxx .']
# ['%mor:coord|and det|a .', "*MOT:you're a what ?"]
# ['%mor:pro|you~v:cop|be&PRES det|a pro:wh|what ?', '*CHI:xxx .']
# ['*MOT:a jumpy ?', '%mor:det|a adj|jump&dn-Y ?']
# ['*MOT:should we put sunglasses on the baby ?', '%mor:aux|should pro:sub|we v|put&ZERO n|sunglass-PL prep|on det|the n|baby']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*MOT:you wanna wear some sunglasses ?', '%mor:pro|you v|want~inf|to v|wear qn|some n|sunglass-PL ?']
# ['*CHI:no .', '%mor:co|no .']
# ['*CHI:baby wants to .', '%mor:n|baby v|want-3S prep|to .']
# ['*MOT:the baby wants to .', '%mor:det|the n|baby v|want-3S prep|to .']
# ['*CHI:can you tie this ?', '%mor:aux|can pro|you v|tie det|this ?']
# ["*INV1:we'll do it once we're done, okay ?", '%mor:pro:sub|we~mod|will aux|do pro|it adv|once pro:sub|we~v:cop|be&PRES adj|done']
# ['*MOT:come here buddy .', '%mor:v|come adv:loc|here n|buddy .']
# ['*CHI:okay .', '%mor:co|okay .']
# ['*CHI:okay .', '%mor:co|okay .']
# ["*MOT:okay, we'll play with this as soon as we're done .", '%mor:co|okay cm|cm pro:sub|we~mod|will v|play prep|with det|this adv|as adv|soon']
# ['*MOT:how many animals are there ?', '%mor:adv:wh|how qn|many n|animal-PL v:cop|be&PRES adv:loc|there ?']
# ['*CHI:one, two, three .', '%mor:det:num|one cm|cm det:num|two cm|cm det:num|three .']
# ["*CHI:there's three .", '%mor:adv:loc|there~v:cop|be&3S det:num|three .']
# ['*MOT:what about those animals ?', '%mor:pro:wh|what adv|about det|those n|animal-PL ?']
# ['*MOT:over there .', '%mor:prep|over adv:loc|there .']
# ['*MOT:and these animals .', '%mor:coord|and det|these n|animal-PL .']
# ['*MOT:count all the animals .', '%mor:v|count qn|all det|the n|animal-PL .']
# ['*CHI:can I have .', '%mor:aux|can pro:sub|I v|have .']
# ['*CHI:hey .', '%mor:co|hey .']
# ['*CHI:I want the balloon back .', '%mor:pro:sub|I v|want det|the n|balloon adv:loc|back .']
# ['*CHI:can I ?', '%mor:aux|can pro:sub|I ?']
# ['*MOT:what do you say ?', '%mor:pro:wh|what aux|do pro|you v|say ?']
# ['*CHI:please .', '%mor:co|please .']
# ['*MOT:please what ?', '%mor:v|please pro:wh|what ?']
# ['*CHI:please I can have the balloon back ?', '%mor:v|please pro:sub|I aux|can v|have det|the n|balloon adv:loc|back ?']
# ['*MOT:please can I have the balloon .', '%mor:v|please aux|can pro:sub|I v|have det|the n|balloon .']
# ['*CHI:please I can have balloon ?', '%mor:v|please pro:sub|I aux|can v|have n|balloon ?']
# ['*MOT:Lester, please can I have the balloon .', '%mor:n:prop|Lester cm|cm v|please aux|can pro:sub|I v|have det|the n|balloon']
# ['*CHI:please can I have a balloon ?', '%mor:v|please aux|can pro:sub|I v|have det|a n|balloon ?']
# ['*MOT:very good .', '%mor:adv:int|very adj|good .']
# ['*MOT:you may .', '%mor:pro|you aux|may .']
# ['*CHI:can you put it on here ?', '%mor:aux|can pro|you v|put&ZERO pro|it prep|on adv:loc|here ?']
# ['*CHI:can you ?', '%mor:aux|can pro|you ?']
# ["*MOT:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .']
# ['*MOT:can I ?', '%mor:aux|can pro:sub|I ?']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:oh yeah ?', '%mor:co|oh co|yeah ?']
# ['*MOT:how do I do it ?', '%mor:adv:wh|how v|do pro:sub|I v|do pro|it ?']
# ['*MOT:how do I do it ?', '%mor:adv:wh|how v|do pro:sub|I v|do pro|it ?']
# ['*CHI:you just do this and put it on .', '%mor:pro|you adv:int|just v|do pro:dem|this coord|and v|put&ZERO pro|it adv|on']
# ['*MOT:oh really ?', '%mor:co|oh adv:int|really ?']
# ['*MOT:just like this ?', '%mor:adv:int|just prep|like pro:dem|this ?']
# ['*CHI:then you pump it .', '%mor:adv:tem|then pro|you v|pump pro|it .']
# ['*CHI:then you do that .', '%mor:adv:tem|then pro|you v|do pro:dem|that .']
# ['*MOT:oh .', '%mor:co|oh .']
# ["*MOT:you're very smart .", '%mor:pro|you~v:cop|be&PRES adv:int|very adj|smart .']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*MOT:okay .', '%mor:co|okay .']
# ['*MOT:I did this .', '%mor:pro:sub|I v|do&PAST det|this .']
# ['*MOT:I put it on .', '%mor:pro:sub|I v|put&ZERO pro|it adv|on .']
# ['*CHI:then .', '%mor:adv:tem|then .']
# ['*MOT:then what ?', '%mor:adv:tem|then pro:wh|what ?']
# ['*MOT:alright .', '%mor:co|alright .']
# ["*MOT:you don't hold this while you're pumping it though .", '%mor:pro|you aux|do~neg|not v|hold det|this n|while pro|you~aux|be&PRES part|pump-PROG']
# ['*MOT:okay, woah .', '%mor:co|okay cm|cm int|woah .']
# ['*MOT:what are you doing ?', '%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?']
# ['*MOT:what are you doing ?', '%mor:pro:wh|what aux|be&PRES pro|you part|do-PROG ?']
# ["*CHI:I'm making a giant balloon .", '%mor:pro:sub|I~aux|be&1S part|make-PROG det|a n|giant n|balloon .']
# ["*MOT:you're making a giant balloon .", '%mor:pro|you~aux|be&PRES part|make-PROG det|a n|giant n|balloon .']
# ['*MOT:what color is the balloon ?', '%mor:pro:wh|what n|color v:cop|be&3S det|the n|balloon ?']
# ['*CHI:red .', '%mor:unk|xxx . ']
# ['%mor:adj|red .', '*MOT:red .']
# ['%mor:adj|red .', '*MOT:what color if you had another color balloon .']
# ['%mor:pro:wh|what n|color conj|if pro|you v|have&PAST qn|another n|color n|balloon', '*MOT:what color would you want ?']
# ['%mor:pro:wh|what n|color aux|will&COND pro|you v|want ?', '*CHI:pink .']
# ['%mor:adj|pink .', '*MOT:pink .']
# ['%mor:adj|pink .', "*MOT:and if you couldn't get a pink balloon ."]
# ['%mor:coord|and conj|if pro|you aux|could~neg|not v|get det|a adj|pink n|balloon', '*MOT:what color would you want then ?']
# ['%mor:pro:wh|what n|color aux|will&COND pro|you v|want adv:tem|then ?', '*CHI:a orange .']
# ['%mor:det|a n|orange .', '*MOT:orange .']
# ['%mor:adj|orange .', "*MOT:if you couldn't have an orange balloon ?"]
# ['%mor:conj|if pro|you aux|could~neg|not v|have det|a n|orange n|balloon ?', '*CHI:xxx .']
# ['*MOT:what color is in the rainbow ?', '%mor:pro:wh|what n|color v:cop|be&3S prep|in det|the n|+n|rain+n|bow ?']
# ["*CHI:I don't know .", '%mor:pro:sub|I aux|do~neg|not v|know .']
# ['*MOT:what ?', '%mor:pro:wh|what ?']
# ["*MOT:you don't know ?", '%mor:pro|you aux|do~neg|not v|know ?']
# ["*MOT:I'm going to take my magic wand and turn you into a frog .", '%mor:pro:sub|I~aux|be&1S part|go-PROG inf|to v|take pro:poss:det|my n|magic']
# ['*MOT:oh, did you hear that ?', '%mor:co|oh cm|cm v|do&PAST pro|you v|hear pro:dem|that ?']
# ['*CHI:yeah .', '%mor:co|yeah .']
# ['*CHI:is this xxx .', '%mor:v:cop|be&3S det|this .']
# ["*MOT:what's the frog saying ?", '%mor:pro:wh|what~aux|be&3S det|the n|frog adj:part|say-PROG ?']
# ["*MOT:I'm going to turn you into a frog with my magic wand .", '%mor:pro:sub|I~aux|be&1S part|go-PROG inf|to v|turn pro|you prep|into det|a']
# ['*MOT:alakazam .', '%mor:?|alakazam .']
# ['*MOT:Lester is a froggie .', '%mor:n:prop|Lester v:cop|be&3S det|a n|frog-DIM .']
# ['*MOT:did it work ?', '%mor:v|do&PAST pro|it v|work ?']
# ['*MOT:are you a frog ?', '%mor:aux|be&PRES pro|you det|a n|frog ?']
# ['*CHI:no .', '%mor:co|no .']
# ['*CHI:abracadabra .', '%mor:?|abracadabra .']
# ['*MOT:oh .', '%mor:co|oh .']
# ['*CHI:I just turned you into xxx .', '%mor:pro:sub|I adv:int|just v|turn-PAST pro|you prep|into .']
# ["*MOT:I'm a vegetable ?", '%mor:pro:sub|I~v:cop|be&1S det|a n|vegetable ?']
# ['*CHI:no, invisible .', '%mor:co|no cm|cm in#adj|visible .']
# ['*MOT:oh invisible .', '%mor:co|oh in#adj|visible .']
# ['*CHI:where you can xxx walls .', '%mor:adv:wh|where pro|you aux|can n|wall-PL .']
# ["*MOT:that's not very nice .", '%mor:pro:dem|that~v:cop|be&3S neg|not adv:int|very adj|nice .']
# ['*MOT:woah, that balloon is huge Lester .', '%mor:int|woah cm|cm rel|that v|balloon v:cop|be&3S adj|huge n:prop|Lester .']
# ['*MOT:what are you gonna do with that balloon ?', '%mor:pro:wh|what aux|be&PRES pro|you v|go-PROG~inf|to v|do prep|with det|that']
# ['*CHI:explode it .', '%mor:v|explode pro|it .']
# ["*MOT:you're gonna explode it ?", '%mor:pro|you~aux|be&PRES v|go-PROG~inf|to v|explode pro|it ?']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-d3990c591e88> in <module>()
#      36         temp = n.split('|')
#      37         p.append(temp[0])
# ---> 38         w.append(temp[1])
#      39     turn.append(t)
#      40     speaker.append(s)
#
# IndexError: list index out of range
