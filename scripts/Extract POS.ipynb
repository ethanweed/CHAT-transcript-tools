# %%
def POS(file):
    import os
    from string import punctuation as p

    os.chdir(pathin)

    removelist = ['\t', '\r']

    with open(file,'r') as f:
        text = f.read()



        for item in removelist:
            text = text.replace(item, '')
        text = text.split('@')

        #print(text)

        for line in text:
            if line.startswith('Participants:'):
                p = line.replace('Participants:', '')
                p = p.split(',')

                p1 = []
                for i, val in enumerate(p):
                    v1 = val.replace(' ','')
                    v2 = v1.replace('\n', '')
                    p1.append(v2[0:3])
        people = p1


    with open(file,'r') as f:
        text = f.read()
        for item in removelist:
            text = text.replace(item, '')
        text = text.split('\n')

        trans = []
        for line in text:
            label = line[1:4]
            if label in people:
                trans.append(line)
            elif label == 'mor':
                trans.append(line)

    grouped = [trans[n:n+2] for n in range(0, len(trans), 2)]

    p = '.!?'

    turn = []
    speaker = []
    mor = []
    for i, val in enumerate(grouped):
        turn.append(i+1)

    for i in grouped:
        s = i[0]
        m = i[1]
        for c in p:
            m = m.replace(c, '')
            m = m.strip()
            m = m.replace('%mor:', '')
        speaker.append(s[1:4])
        mor.append(m)


    turn = []
    speaker = []
    pss = []
    wds = []
    for i, val in enumerate(z):
        x = z[i]
        t = x[0]
        s = x[1]
        m = x[2]
        m = m.split(' ')
        p = []
        w = []
        for n in m:
            temp = n.split('|')
            p.append(temp[0])
            w.append(temp[1])
        turn.append(t)
        speaker.append(s)
        pss.append(p)
        wds.append(w)



    pw = list(zip(turn,speaker,pos,word))

    lines = []
    for i in pw:
        num = str(i[0])
        speaker = i[1]
        wds = i[3]
        pss = i[2]
        for j, val in enumerate(pss):
            p = pss[j]
            w = wds[j]
            temp = num + ',' + speaker + ',' + w + ',' + p + '\n'
            lines.append(temp)      

    header = 'Turn,' + 'Speaker,' + 'Word' + 'POS' + '\n'
    data = ''.join(lines)
    output = header + data
    return(output)

# %%
pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/raw_cohorts_2_3/'
pathout = '/Users/ethan/Desktop/POS/'
file = 'AD.Visit1.txt'

a = POS(file)

# %%
# Out:
# 'Turn,Speaker,WordPOS\n1,MOT,look,v\n1,MOT,Ad,n:prop\n2,MOT,look,v\n2,MOT,at,prep\n2,MOT,all,qn\n2,MOT,these,det\n2,MOT,toy-PL,n\n3,CHI,xxx,unk\n4,MOT,toy-PL,n\n4,MOT,yeah,co\n5,MOT,what,pro:wh\n5,MOT,do,aux\n5,MOT,you,pro\n5,MOT,see,v\n6,CHI,xxx,unk\n7,MOT,what,pro:wh\n7,MOT,do,aux\n7,MOT,you,pro\n7,MOT,see,v\n8,MOT,kitty,n\n8,MOT,on,prep\n8,MOT,the,det\n8,MOT,book,n\n9,MOT,what~v,pro:wh\n9,MOT,that,pro:dem\n10,MOT,be&3S,v\n10,MOT,it,pro\n10,MOT,squishy,adj\n11,MOT,squishy,adj\n11,MOT,ball,n\n12,MOT,come,v\n12,MOT,here,adv:loc\n13,MOT,whoa,co\n14,MOT,it~v,pro\n14,MOT,bouncy,adj\n15,MOT,what~v,pro:wh\n15,MOT,in,adv:loc\n15,MOT,there,adv:loc\n16,CHI,eh,fil\n17,MOT,what~v,pro:wh\n17,MOT,in,adv:loc\n17,MOT,there,adv:loc\n18,MOT,do&3S,aux\n18,MOT,it,pro\n18,MOT,come,v\n18,MOT,out,n\n19,CHI,xxx,unk\n20,MOT,where,adv:wh\n20,MOT,be&3S,v\n20,MOT,it,pro\n21,MOT,where,adv:wh\n21,MOT,be&3S,v\n21,MOT,it,pro\n22,SIB,try,n\n22,SIB,to,inf\n22,SIB,push,v\n22,SIB,on,prep\n22,SIB,the,det\n22,SIB,other,qn\n22,SIB,side,n\n23,MOT,where,adv:wh\n23,MOT,be&3S,v\n23,MOT,it,pro\n24,SIB,push,v\n24,SIB,on,prep\n24,SIB,the,det\n24,SIB,other,qn\n24,SIB,side,n\n25,MOT,keep,v\n25,MOT,look-PROG,part\n26,MOT,I,pro\n26,MOT,hear,v\n26,MOT,music,n\n27,MOT,who~v,pro:wh\n27,MOT,in,adv:loc\n27,MOT,there,adv:loc\n28,MOT,look,v\n29,MOT,who~v,pro:wh\n29,MOT,there,adv:loc\n30,MOT,ooh,co\n30,MOT,be&3S,v\n30,MOT,that,pro:dem\n30,MOT,the,det\n30,MOT,baby,n\n31,MOT,look,v\n32,CHI,xxx,unk\n33,MOT,how,adv:wh\n33,MOT,do&3S,aux\n33,MOT,this,det\n33,MOT,work,n\n34,MOT,it~v,pro\n34,MOT,mommy,n\n34,MOT,proof,n\n35,MOT,ooh,co\n35,MOT,Ad,n:prop\n36,MOT,you,pro\n36,MOT,have,v\n36,MOT,a,det\n36,MOT,bottle,n\n37,MOT,ooh,co\n37,MOT,who,pro:wh\n37,MOT,come&PAST,v\n37,MOT,out,n\n38,CHI,mama,n\n39,MOT,who~v,pro:wh\n39,MOT,that,pro:dem\n40,MOT,be&3S,v\n40,MOT,that,pro:dem\n40,MOT,the,det\n40,MOT,clown,n\n41,MOT,be&3S,v\n41,MOT,that,pro:dem\n41,MOT,the,det\n41,MOT,clown,n\n42,MOT,oh,co\n42,MOT,yeah,co\n42,MOT,come,v\n42,MOT,here,adv:loc\n42,MOT,let-3S,v\n43,CHI,xxx,unk\n44,MOT,ooh,co\n44,MOT,look,v\n44,MOT,at,prep\n44,MOT,us,pro\n44,MOT,wash-PROG,part\n45,MOT,wash-PROG,part\n46,MOT,who,pro:wh\n46,MOT,can,aux\n46,MOT,go,v\n46,MOT,in,adv:loc\n46