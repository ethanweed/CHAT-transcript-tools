# %%
#read file into python

import os
import glob
from string import punctuation as p

pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/raw_cohorts_2_3/'
pathout = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/POS-Letty/'

os.chdir(pathin)

removelist = ['\t', '\r']

for file in glob.glob('*.txt'):
    try:

        with open(file,'r') as f:
            text = f.read()
            for item in removelist:
                text = text.replace(item, '')
            text = text.split('@')

            #print(text)

            for line in text:
                if line.startswith('Participants:'):
                    p = line.replace('Participants:', '')
                    p = p.split(',')

                    p1 = []
                    for i, val in enumerate(p):
                        v1 = val.replace(' ','')
                        v2 = v1.replace('\n', '')
                        p1.append(v2[0:3])
            people = p1

        with open(file,'r') as f:
            text = f.read()
            for item in removelist:
                text = text.replace(item, '')
            text = text.split('\n')

            trans = []
            for line in text:
                label = line[1:4]
                if label in people:
                    trans.append(line)
                elif label == 'mor':
                    trans.append(line)

        grouped = [trans[n:n+2] for n in range(0, len(trans), 2)]

        p = '.!?'

        turn = []
        speaker = []
        mor = []
        for i, val in enumerate(grouped):
            turn.append(i+1)

        for i in grouped:
            s = i[0]
            m = i[1]
            for c in p:
                m = m.replace(c, '')
                m = m.strip()
                m = m.replace('%mor:', '')
            speaker.append(s[1:4])
            mor.append(m)

        z = list(zip(turn, speaker, mor))


        turn = []
        speaker = []
        pss = []
        wds = []
        for i, val in enumerate(z):
            x = z[i]
            t = x[0]
            s = x[1]
            m = x[2]
            m = m.split(' ')
            p = []
            w = []
            for n in m:
                temp = n.split('|')
                p.append(temp[0])
                w.append(temp[1])
            turn.append(t)
            speaker.append(s)
            pss.append(p)
            wds.append(w) 

        pw = list(zip(turn,speaker,pss,wds))


        lines = []
        for i in pw:
            num = str(i[0])
            speaker = i[1]
            wds = i[3]
            pss = i[2]
            for j, val in enumerate(pss):
                p = pss[j]
                w = wds[j]
                temp = num + ',' + speaker + ',' + w + ',' + p + '\n'
                lines.append(temp)      

        header = 'Turn,' + 'Speaker,' + 'Word' + 'POS' + '\n'
        data = ''.join(lines)
        output = header + data

        filename = pathout + file[:-4] + '.csv'
        with open(filename, 'a+') as newfile:
            newfile.write(output)
            newfile.close()
        #print('Done with ' + file)
    except Exception as e:
        print(str(e) + ' in ' + file)
        
print('All done!')
# Out:
# list index out of range in Lester.Visit6.txt
# list index out of range in Albert.Visit1.txt
# list index out of range in Alfie.Visit1.txt
# list index out of range in Allison.Visit2.txt
# list index out of range in LD.Visit6.txt
# list index out of range in MM.Visit2.txt
# list index out of range in MM.Visit3.txt
# list index out of range in Jack.Visit6.txt
# list index out of range in Lester.Visit5.txt
# list index out of range in AH.Visit2.txt
# list index out of range in MM.Visit1.txt
# list index out of range in LL.Visit3.txt
# list index out of range in LL.Visit2.txt
# list index out of range in Lester.Visit4.txt
# list index out of range in Allison.Visit4.txt
# list index out of range in MM.Visit4.txt
# list index out of range in SA.Visit5.txt
# list index out of range in MM.Visit5.txt
# list index out of range in Caleb.Visit5.txt
# list index out of range in LD.Visit1.txt
# list index out of range in Allison.Visit5.txt
# list index out of range in JGII.Visit1.txt
# list index out of range in Lester.Visit1.txt
# list index out of range in Lester.Visit3.txt
# list index out of range in LD.Visit3.txt
# list index out of range in Witt.Visit5.txt
# list index out of range in JP.Visit4.txt
# list index out of range in LL.Visit5.txt
# list index out of range in LL.Visit4.txt
# list index out of range in Caleb.Visit6.txt
# list index out of range in LD.Visit2.txt
# list index out of range in Allison.Visit6.txt
# list index out of range in Lester.Visit2.txt
# list index out of range in Eduardo.Visit6.txt
# list index out of range in John.Visit5.txt
# list index out of range in Eduardo.Visit5.txt
# list index out of range in MJ.Visit5.txt
# list index out of range in VC.Visit5.txt
# list index out of range in VC.Visit4.txt
# list index out of range in MJ.Visit4.txt
# list index out of range in Eduardo.Visit4.txt
# list index out of range in John.Visit6.txt
# list index out of range in Adam.Visit2.txt
# list index out of range in Kara.Visit6.txt
# list index out of range in KM.Visit5.txt
# list index out of range in VC.Visit1.txt
# list index out of range in Eduardo.Visit1.txt
# list index out of range in RB.Visit4.txt
# list index out of range in Kara.Visit5.txt
# list index out of range in Adam.Visit5.txt
# list index out of range in John.Visit1.txt
# list index out of range in MJ.Visit3.txt
# list index out of range in Eduardo.Visit3.txt
# list index out of range in VC.Visit3.txt
# list index out of range in VC.Visit2.txt
# list index out of range in Eduardo.Visit2.txt
# list index out of range in MJ.Visit2.txt
# list index out of range in Annie.Visit5.txt
# list index out of range in Adam.visit4.txt
# list index out of range in Frankie.Visit5.txt
# list index out of range in ES.Visit4.txt
# list index out of range in AD.Visit4.txt
# list index out of range in Todd.visit5.txt
# list index out of range in JB.Visit4.txt
# list index out of range in RR.Visit5.txt
# list index out of range in AR.Visit2.txt
# list index out of range in JG.Visit1.txt
# list index out of range in Frankie.Visit4.txt
# list index out of range in CD2.Visit4.txt
# list index out of range in Johan.Visit6.txt
# list index out of range in Johan.Visit4.txt
# list index out of range in Frankie.Visit6.txt
# list index out of range in Charles.visit2.txt
# list index out of range in JB.Visit6.txt
# list index out of range in JG.Visit2.txt
# list index out of range in Johan.Visit5.txt
# list index out of range in AR.Visit5.txt
# list index out of range in RR.Visit2.txt
# list index out of range in JB.Visit2.txt
# list index out of range in AR.Visit6.txt
# list index out of range in JB.Visit1.txt
# list index out of range in JG.Visit4.txt
# list index out of range in Frankie.Visit1.txt
# list index out of range in Johan.Visit3.txt
# list index out of range in MD.Visit6.txt
# list index out of range in CH.Visit2.txt
# list index out of range in Marius.Visit6.txt
# list index out of range in AS2.visit6.txt
# list index out of range in Tina.Visit3.txt
# list index out of range in MC.Visit4.txt
# list index out of range in AS2.visit2.txt
# list index out of range in Tina.Visit6.txt
# list index out of range in SB.Visit2.txt
# list index out of range in CH.Visit4.txt
# list index out of range in Bernie.Visit2.txt
# list index out of range in Tina.Visit4.txt
# list index out of range in Tina.Visit5.txt
# list index out of range in SB.Visit1.txt
# list index out of range in MC.Visit2.txt
# All done!

# %%
filename = pathout + 'test' + '.csv'
with open(filename, 'a+') as newfile:
    newfile.write(output)
newfile.close()

# %%
file
# Out:
# 'Lester.Visit6.txt'

# %%
pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/raw_cohorts_2_3/'
file = 'AD.Visit1.txt'
a = POS(pathin,file)
b = a[0]
b

# %%
	import os
	from string import punctuation as p


	os.chdir(pathin)

	removelist = ['\t', '\r']




	with open(file,'r') as f:
		text = f.read()
		for item in removelist:
			text = text.replace(item, '')
			text = text.split('@')

		#print(text)
    
	for line in text:
		if line.startswith('Participants:'):
			p = line.replace('Participants:', '')
			p = p.split(',')

		p1 = []
		for i, val in enumerate(p):
			v1 = val.replace(' ','')
			v2 = v1.replace('\n', '')
			p1.append(v2[0:3])
		people = p1

	with open(file,'r') as f:
		text = f.read()
		for item in removelist:
			text = text.replace(item, '')
			text = text.split('\n')

		trans = []
		for line in text:
			label = line[1:4]
			if label in people:
		  		trans.append(line)
			elif label == 'mor':
		  		trans.append(line)

	grouped = [trans[n:n+2] for n in range(0, len(trans), 2)]
	#print(grouped)

	p = '.!?'

	turn = []
	speaker = []
	mor = []
	for i, val in enumerate(grouped):
		turn.append(i+1)

	for i in grouped:
		s = i[0]
		m = i[1]
		for c in p:
			m = m.replace(c, '')
			m = m.strip()
			m = m.replace('%mor:', '')
			speaker.append(s[1:4])
			mor.append(m)

	z = list(zip(turn, speaker, mor))

	turn = []
	speaker = []
	pss = []
	wds = []
	for i, val in enumerate(z):
		x = z[i]
		t = x[0]
		s = x[1]
		m = x[2]
		m = m.split(' ')
		p = []
		w = []
		for n in m:
			temp = n.split('|')
			p.append(temp[0])
			w.append(temp[1])
		turn.append(t)
		speaker.append(s)
		pss.append(p)
		wds.append(w) 

	pw = list(zip(turn,speaker,pss,wds))
	print(pw)

	lines = []
	for i in pw:
		num = str(i[0])
		speaker = i[1]
		wds = i[3]
		pss = i[2]
		for j, val in enumerate(pss):
			p = pss[j]
			w = wds[j]
			temp = num + ',' + speaker + ',' + w + ',' + p + '\n'
			lines.append(temp)      

	header = 'Turn,' + 'Speaker,' + 'Word' + 'POS' + '\n'
	data = ''.join(lines)
	output = header + data

# %%
from os import chdir as cd
import glob

cd('/Users/ethan/Documents/GitHub/CHAT-transcript-tools/functions/')
from ExtractPOS import POS


pathin = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/raw_cohorts_2_3/'
pathout = '/Users/ethan/Dropbox/Research/Projects/Projects_current/uconn/text_processing/POS-Letty/'

cd(pathin)

for file in glob.glob('*.txt'):
    a = POS(pathin, file)
    filename = a[0]
    output = pathout + a[1]
    with open(filename, 'a+') as newfile:
        newfile.write(output)
        newfile.close()
